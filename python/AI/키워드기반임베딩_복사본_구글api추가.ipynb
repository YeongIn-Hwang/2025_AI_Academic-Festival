# %%
API_KEY = "AIzaSyBEl50H0xV7SnyNwcc0Yo-Ru-iiTXTBePc"

PLACE_TYPES = [
    "tourist_attraction",
    "cafe",
    "bar",
    "bakery",
    "restaurant",
    "shopping_mall",
]

import json
import numpy as np
import requests
import math
import re
import html
import time as tm
from sentence_transformers import SentenceTransformer
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
from collections import defaultdict
from datetime import time, datetime, timedelta

# %%
# 사용자 입력
query = input("어느 지역을 중심으로 여행 경로를 짜드릴까요? (예: 경복궁, 강남역): \n")
method = int(input("어떤 방식으로 여행하시나요? 1 : 도보 2 : 대중교통, 3 : 직접 운전\n"))
radius = {1: "3000", 2: "15000", 3: "30000"}.get(method)

# 지오코딩
geo_url = "https://maps.googleapis.com/maps/api/geocode/json"
geo_params = {
    "address": query,
    "key": API_KEY,
    "language": "ko"
}
geo_res = requests.get(geo_url, params=geo_params).json()

if not geo_res["results"]:
    print("위치를 찾을 수 없습니다. 다시 입력해 주세요.")
    exit()

location = geo_res["results"][0]["geometry"]["location"]
lat, lng = location["lat"], location["lng"]

def compute_review_weight_log(reviews, max_reviews=1000):
    if reviews is None or reviews <= 0:
        return 0.0

    # 1 이상이어야 로그 계산 가능
    log_base = 10
    normalized = math.log(min(reviews, max_reviews), log_base) / math.log(max_reviews, log_base)
    return round(normalized, 4)

# 신뢰도 점수 계산 함수
def compute_trust_score(rating, reviews, latest_review_time_str=""):
    if rating is None or reviews is None:
        return 0.0

    # 로그 기반 신뢰도 계산
    review_weight = compute_review_weight_log(reviews, max_reviews=1000)

    # 최신성 보너스
    bonus_ratio = 0.0
    try:
        if "day" in latest_review_time_str or "week" in latest_review_time_str:
            bonus_ratio = 0.10
        elif "month" in latest_review_time_str:
            months = int(latest_review_time_str.split()[0])
            if months <= 1:
                bonus_ratio = 0.10
            elif months <= 6:
                bonus_ratio = 0.05
    except:
        bonus_ratio = 0.0

    trust_score = rating * review_weight * (1 + bonus_ratio)
    return round(min(trust_score, 5.0), 4)

# 장소 검색 (리뷰는 안 받음)
def search_places_basic(place_type):
    url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
    params = {
        "location": f"{lat},{lng}",
        "radius": radius,
        "type": place_type,
        "language": "ko",
        "key": API_KEY
    }

    candidates = []
    for _ in range(2):  # 최대 2페이지
        res = requests.get(url, params=params).json()
        results = res.get("results", [])
        for place in results:
            rating = place.get("rating", 0)
            user_ratings_total = place.get("user_ratings_total", 0)
            if user_ratings_total < 1 or rating < 3.5:
                continue
            location = place.get("geometry", {}).get("location", {})
            place_lat = location.get("lat")
            place_lng = location.get("lng")
            candidates.append({
                "place_id": place.get("place_id"),
                "name": place.get("name"),
                "vicinity": place.get("vicinity", "주소 없음"),
                "rating": rating,
                "user_ratings_total": user_ratings_total,
                "trust_score": compute_trust_score(rating, user_ratings_total),
                "type": place_type,
                "lat": place_lat,
                "lng": place_lng
            })
        token = res.get("next_page_token")
        if not token:
            break
        tm.sleep(2)
        params = {"pagetoken": token, "key": API_KEY, "language": "ko"}
    # 상위 20개만 반환
    candidates.sort(key=lambda x: x["trust_score"], reverse=True)
    return candidates[:40]

# 리뷰 요청 함수
def get_reviews_and_business_info(place_id):
    url = "https://maps.googleapis.com/maps/api/place/details/json"
    params = {
        "place_id": place_id,
        "fields": "review,business_status,opening_hours",
        "language": "ko",
        "key": API_KEY
    }
    res = requests.get(url, params=params).json()
    result = res.get("result", {})

    # 리뷰
    reviews = result.get("reviews", [])
    texts = [r["text"] for r in reviews[:5]]
    latest_time = reviews[0]["relative_time_description"] if reviews else ""

    # 영업 상태
    business_status = result.get("business_status", "UNKNOWN")

    # 운영 시간
    opening_hours = result.get("opening_hours", {})
    open_now = opening_hours.get("open_now", None)
    weekday_text = opening_hours.get("weekday_text", [])

    return texts, latest_time, business_status, open_now, weekday_text

# 전체 장소 누적 저장
all_places = []

print(f"\n'{query}' 주변 검색 결과:")

for place_type in PLACE_TYPES:
    top_places = search_places_basic(place_type)
    print(f"\n{place_type.title()} (신뢰도 상위 20개)")
    for place in top_places:
        reviews, latest_time, biz_status, open_now, weekday_hours = get_reviews_and_business_info(place["place_id"])
        place["reviews"] = reviews
        place["trust_score"] = compute_trust_score(place["rating"], place["user_ratings_total"], latest_time)
        place["business_status"] = biz_status
        place["open_now"] = open_now
        place["weekday_text"] = weekday_hours
        all_places.append(place)
# Out:
# 🔎 '신도림' 주변 검색 결과:
#
# 🔹 Tourist_Attraction (신뢰도 상위 20개)
#
# 🔹 Cafe (신뢰도 상위 20개)
#
# 🔹 Bar (신뢰도 상위 20개)
#
# 🔹 Bakery (신뢰도 상위 20개)
#
# 🔹 Restaurant (신뢰도 상위 20개)
#
# 🔹 Shopping_Mall (신뢰도 상위 20개)

# %%
with open("all_places.json", "w", encoding="utf-8") as f:
    json.dump(all_places, f, ensure_ascii=False, indent=2)

# %%
with open("all_places.json", "r", encoding="utf-8") as f:
    all_places = json.load(f)

# %%
def clean_review(text):
    if not isinstance(text, str):
        return None

    text = html.unescape(text)
    text = text.strip()

    if len(text) < 3:
        return None

    if not re.search("[가-힣]", text):  # 한글 없는 외국어 리뷰 제거
        return None

    text = re.sub(r"(.)\1{2,}", r"\1\1", text)  # 반복 문자 정리
    text = re.sub(r"[^\w\s가-힣.,!?]", "", text)  # 이모지, 특수문자 제거
    text = text[:300]  # 너무 긴 리뷰 자르기

    return text if text else None

for place in all_places:
    original_reviews = place.get("reviews", [])
    cleaned_reviews = []

    for review in original_reviews:
        cleaned = clean_review(review)
        if cleaned:
            cleaned_reviews.append(cleaned)

    place["reviews"] = cleaned_reviews  # 전처리된 리뷰로 덮어쓰기

# %%
# 모델 불러오기 (한 줄로 끝)
model = SentenceTransformer("snunlp/KR-SBERT-V40K-klueNLI-augSTS")

def get_sbert_embedding(text):
    if not isinstance(text, str) or not text.strip():
        return np.zeros(model.get_sentence_embedding_dimension())
    return model.encode(text, convert_to_numpy=True)

def get_sbert_review_vector(reviews):
    embeddings = [
        get_sbert_embedding(review)
        for review in reviews if review.strip()
    ]
    if embeddings:
        return np.mean(embeddings, axis=0)
    else:
        return np.zeros(model.get_sentence_embedding_dimension())

def get_place_vector_with_name(place, review_weight=1.0, name_weight=0):
    reviews = place.get("reviews", [])
    name = place.get("name", "")

    review_vec = get_sbert_review_vector(reviews)
    name_vec = get_sbert_embedding(name)

    total_weight = review_weight + name_weight
    final_vec = (review_weight * review_vec + name_weight * name_vec) / total_weight
    return final_vec

# 문맥 벡터 생성 및 저장
for place in all_places:
    if "reviews" in place and "name" in place:
        place["review_vector"] = get_place_vector_with_name(place)
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# modules.json:   0%|          | 0.00/229 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/124 [00:00<?, ?B/s]
# README.md: 0.00B [00:00, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/707 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/467M [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/467M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/394 [00:00<?, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1750: FutureWarning: `encoder_attention_mask` is deprecated and will be removed in version 4.55.0 for `BertSdpaSelfAttention.forward`.
#   return forward_call(*args, **kwargs)

# %%
def clean_keyword(text):
    if not isinstance(text, str):
        return None

    text = html.unescape(text)
    text = text.strip()

    if not re.search("[가-힣]", text):  # 한글 없는 외국어 리뷰 제거
        return None

    text = re.sub(r"(.)\1{2,}", r"\1\1", text)  # 반복 문자 정리
    text = re.sub(r"[^\w\s가-힣.,!?]", "", text)  # 이모지, 특수문자 제거
    text = text[:300]  # 너무 긴 키워드 자르기

    return text if text else None

# %%
# 1. 선호 키워드 평균 임베딩
hope_embeddings = [get_sbert_embedding(k) for k in keyword_hope if k]
if hope_embeddings:
    hope_mean_vector = np.mean(hope_embeddings, axis=0)
else:
    hope_mean_vector = np.zeros(model.get_sentence_embedding_dimension())

# 2. 비선호 키워드 평균 임베딩
nonhope_embeddings = [get_sbert_embedding(k) for k in keyword_nonhope if k]
if nonhope_embeddings:
    nonhope_mean_vector = np.mean(nonhope_embeddings, axis=0)
else:
    nonhope_mean_vector = np.zeros(model.get_sentence_embedding_dimension())

# 3. 유사도 계산 함수 (클러스터 대신 단일 벡터 기준)
def compute_hope_score(review_vector, name_vector, hope_mean_vector, alpha=0.2):
    sim_review = (
        cosine_similarity([review_vector], [hope_mean_vector])[0][0]
        if np.linalg.norm(review_vector) > 0 and np.linalg.norm(hope_mean_vector) > 0
        else 0.0
    )
    sim_name = (
        cosine_similarity([name_vector], [hope_mean_vector])[0][0]
        if np.linalg.norm(name_vector) > 0 and np.linalg.norm(hope_mean_vector) > 0
        else 0.0
    )
    score = (1 - alpha) * sim_review + alpha * sim_name
    return round(score, 4)

# 4. 모든 장소에 대해 점수 계산
for place in all_places:
    review_vec = place.get("review_vector")
    name_vec = get_sbert_embedding(place.get("name", ""))
    if review_vec is not None:
        place["hope_score"] = compute_hope_score(
            review_vec, name_vec, hope_mean_vector, alpha=0.2
        )

# 5. 타입별 정렬 및 출력
type_grouped = defaultdict(list)
for place in all_places:
    if "hope_score" in place:
        type_grouped[place["type"]].append(place)

for place_type, places in type_grouped.items():
    print(f"\n📂 Type: {place_type}")
    sorted_places = sorted(places, key=lambda x: x["hope_score"], reverse=True)
    for p in sorted_places[:10]:
        print(f"  - {p['name']} | 점수: {p['hope_score']:.4f}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-4020675882.py in <cell line: 0>()
#       1 # 1. 선호 키워드 평균 임베딩
# ----> 2 hope_embeddings = [get_sbert_embedding(k) for k in keyword_hope if k]
#       3 if hope_embeddings:
#       4     hope_mean_vector = np.mean(hope_embeddings, axis=0)
#       5 else:
#
# NameError: name 'keyword_hope' is not defined

# %%
# 이름과 리뷰를 함께 고려한 벡터 (가중치 조절 가능)
def get_combined_place_vector(place, review_weight=1.0, name_weight=1.0):
    review_vec = place.get("review_vector", np.zeros(model.get_sentence_embedding_dimension()))
    name_vec = get_sbert_embedding(place.get("name", ""))

    if np.linalg.norm(review_vec) == 0 and np.linalg.norm(name_vec) == 0:
        return np.zeros(model.get_sentence_embedding_dimension())

    total_weight = review_weight + name_weight
    return (review_weight * review_vec + name_weight * name_vec) / total_weight

# 장소별 비선호 유사도 계산 (이름 포함)
for place in all_places:
    combined_vec = get_combined_place_vector(place, review_weight=1.0, name_weight=1.0)
    if np.linalg.norm(combined_vec) > 0 and np.linalg.norm(nonhope_mean_vector) > 0:
        score = cosine_similarity([combined_vec], [nonhope_mean_vector])[0][0]
        place["nonhope_score"] = round(score, 4)
    else:
        place["nonhope_score"] = 0.0

# 타입별로 그룹화 및 출력
type_to_places = defaultdict(list)
for place in all_places:
    type_to_places[place["type"]].append(place)

print("\n비선호 키워드 유사도 (타입별 상위 3개씩):")
for place_type, places in type_to_places.items():
    print(f"\n🔹 {place_type.title()}:")
    top_places = sorted(places, key=lambda x: x["nonhope_score"], reverse=True)[:10]
    for i, place in enumerate(top_places, 1):
        print(f"{i}. {place['name']}")
        print(f"비선호 유사도: {place['nonhope_score']:.4f} | 평점: {place['rating']} | 리뷰 수: {place['user_ratings_total']}")

# %%
def convert_place_for_json(place):
    p = place.copy()

    # review_vector는 저장하지 않음
    p.pop("review_vector", None)

    # name_vector는 numpy일 경우 변환
    if isinstance(p.get("name_vector"), np.ndarray):
        p["name_vector"] = p["name_vector"].tolist()

    if "cluster_scores" in p:
        p["cluster_scores"] = list(map(float, p["cluster_scores"]))
    if "nonhope_score" in p:
        p["nonhope_score"] = float(p["nonhope_score"])

    return p

for place in all_places:
    place["in_timetable"] = False

json_ready = [convert_place_for_json(p) for p in all_places]

with open("all_places_embedding.json", "w", encoding="utf-8") as f:
    json.dump(json_ready, f, ensure_ascii=False, indent=2)

print("저장 완료")

# %%
with open("all_places_embedding.json", "r", encoding="utf-8") as f:
    all_places = json.load(f)

# %%
def get_score_ranges(all_places):
    hope_scores = [place["hope_score"] for place in all_places if "hope_score" in place]
    nonhope_scores = [place["nonhope_score"] for place in all_places if "nonhope_score" in place]

    if not hope_scores or not nonhope_scores:
        return None  # 데이터가 없을 경우

    return {
        "hope": {
            "min": min(hope_scores),
            "max": max(hope_scores)
        },
        "nonhope": {
            "min": min(nonhope_scores),
            "max": max(nonhope_scores)
        }
    }

# 분단위 시간 차이 계산 함수
def time_diff_minutes(t1, t2):
    dt1 = datetime.combine(datetime.today(), t1)
    dt2 = datetime.combine(datetime.today(), t2)
    return abs((dt1 - dt2).total_seconds() / 60)

time_table = []

class ScheduleItem:
    def __init__(self, title, start, end, place_type, location_info=None):
        self.title = title #지역 이름
        self.start = start  # 시작시간
        self.end = end      # 종료시간
        self.place_type = place_type #명소, 카페,
        self.location_info = location_info  #위도, 경도

def generate_empty_slots(time_table, day_start=time(9, 0), day_end=time(23, 59)):
    empty_slots = []

    def to_datetime(t):
        return datetime.combine(datetime.today(), t)

    # 정렬된 타임테이블로 가정
    sorted_table = sorted(time_table, key=lambda x: x.start)

    # Step 1. 처음 ~ 첫 일정 전 구간
    if not sorted_table or sorted_table[0].start > day_start:
        empty_slots += split_empty_range(day_start, sorted_table[0].start if sorted_table else day_end)

    # Step 2. 일정 사이 빈 공간 찾기
    for i in range(len(sorted_table) - 1):
        current_end = sorted_table[i].end
        next_start = sorted_table[i + 1].start
        if current_end < next_start:
            empty_slots += split_empty_range(current_end, next_start)

    # Step 3. 마지막 일정 ~ 하루 끝
    if sorted_table and sorted_table[-1].end < day_end:
        empty_slots += split_empty_range(sorted_table[-1].end, day_end)

    return empty_slots

def split_empty_range(start_time, end_time):
    slots = []
    dt_start = datetime.combine(datetime.today(), start_time)
    dt_end = datetime.combine(datetime.today(), end_time)
    gap_minutes = int((dt_end - dt_start).total_seconds() // 60)

    if gap_minutes < 90:
        return []  # 너무 짧으면 무시

    elif gap_minutes < 120:
        # 1시간 30분 이상 2시간 미만 → 하나의 슬롯
        slots.append(ScheduleItem(None, start_time, end_time, None))
    else:
        # 2시간 단위로 나누기
        dt_cursor = dt_start
        while (dt_end - dt_cursor).total_seconds() >= 120 * 60:
            dt_next = dt_cursor + timedelta(minutes=120)
            slots.append(ScheduleItem(None, dt_cursor.time(), dt_next.time(), None))
            dt_cursor = dt_next

        # 남은 시간 처리
        remaining_minutes = int((dt_end - dt_cursor).total_seconds() // 60)
        if 120 <= remaining_minutes <= 210:  # 2시간 이상 3시간 30분 이하면 하나로 묶기
            slots.append(ScheduleItem(None, dt_cursor.time(), dt_end.time(), None))
        elif remaining_minutes >= 90:
            # 1시간 30분 이상이면 마지막 슬롯으로도 인정
            slots.append(ScheduleItem(None, dt_cursor.time(), dt_end.time(), None))

    return slots

# %%
def place_location_info(place_name, api_key):
    import requests

    url = "https://maps.googleapis.com/maps/api/place/textsearch/json"
    params = {
        "query": place_name,
        "key": api_key,
        "language": "ko"
    }

    res = requests.get(url, params=params).json()
    if not res.get("results"):
        return None

    top_result = res["results"][0]
    return {
        "name": top_result.get("name"),
        "lat": top_result.get("geometry", {}).get("location", {}).get("lat"),
        "lng": top_result.get("geometry", {}).get("location", {}).get("lng")
    }

def create_empty_daily_tables(API_KEY, start_date_str, end_date_str,
                              first_day_start_time, last_day_end_time,
                              start_location, final_end_location,
                              accommodation_location,
                              default_start_time=time(9, 0), default_end_time=time(23, 0)):
    """
    여행 시작~종료 날짜 기준으로, 현실적인 조건 반영:
    - 첫날만 사용자 시작시간/장소
    - 마지막 날만 사용자 종료시간/장소
    - 나머지는 숙소에서 시작/종료
    """
    from datetime import datetime, timedelta

    start_date = datetime.strptime(start_date_str, "%Y-%m-%d").date()
    end_date = datetime.strptime(end_date_str, "%Y-%m-%d").date()
    num_days = (end_date - start_date).days + 1

    daily_tables = {}
    table_place_info = {}

    for i in range(num_days):
        date = start_date + timedelta(days=i)
        date_str = date.strftime("%Y-%m-%d")
        weekday = date.strftime("%A")

        is_first_day = i == 0
        is_last_day = i == (num_days - 1)

        # 시간 설정
        start_time = first_day_start_time if is_first_day else default_start_time
        end_time = last_day_end_time if is_last_day else default_end_time

        # 위치 설정
        start_loc = start_location if is_first_day else accommodation_location
        end_loc = final_end_location if is_last_day else accommodation_location

        # 빈 슬롯 생성
        slots = split_empty_range(start_time, end_time)

        table_place_info["시작위치"] = place_location_info(start_location, API_KEY)
        table_place_info["종료위치"] = place_location_info(final_end_location, API_KEY)
        table_place_info["숙소"] = place_location_info(accommodation_location, API_KEY)

        start_loc = table_place_info["시작위치"]["name"] if is_first_day else table_place_info["숙소"]["name"]
        end_loc = table_place_info["종료위치"]["name"] if is_last_day else table_place_info["숙소"]["name"]

        daily_tables[date_str] = {
            "weekday": weekday,
            "start_location": start_loc,
            "end_location": end_loc,
            "schedule": slots
        }

    return table_place_info, daily_tables

API_KEY = "AIzaSyBEl50H0xV7SnyNwcc0Yo-Ru-iiTXTBePc"

table_place_info, tables = create_empty_daily_tables(
    API_KEY,
    start_date_str="2025-08-01",
    end_date_str="2025-08-03",
    first_day_start_time=time(10, 0),
    last_day_end_time=time(21, 0),
    start_location="신도림역",
    final_end_location="신도림역",
    accommodation_location="신도림 숙소"
)

def insert_initial_schedule_items_dynamic(daily_tables, table_place_info):
    """
    일정 테이블에 시작 전/종료 후 임의 일정 삽입
    - 시작 전: start_time 기준, 1시간 전 일정
    - 종료 후: end_time 기준, 1시간 후 일정
    """
    for idx, (date, info) in enumerate(daily_tables.items()):
        schedule = info["schedule"]
        start_time = schedule[0].start if schedule else time(9, 0)
        end_time = schedule[-1].end if schedule else time(21, 0)

        items_to_insert = []

        # 시작 전 일정
        if idx == 0:
            # 첫날 → 출발지
            title = table_place_info["시작위치"]["name"]
            loc_info = table_place_info["시작위치"]
            new_start = (datetime.combine(datetime.today(), start_time) - timedelta(hours=1)).time()
            items_to_insert.append(ScheduleItem(title, new_start, start_time, "start", loc_info))
        else:
            # 중간날 or 마지막날 → 숙소
            title = table_place_info["숙소"]["name"]
            loc_info = table_place_info["숙소"]
            new_start = (datetime.combine(datetime.today(), start_time) - timedelta(hours=1)).time()
            items_to_insert.append(ScheduleItem(title, new_start, start_time, "accommodation", loc_info))

        # 종료 후 일정
        if idx == 0 and len(daily_tables)!=0:
            # 첫날 → 도착지 (하루 마무리용)
            title = table_place_info["숙소"]["name"]
            loc_info = table_place_info["숙소"]
        elif idx == len(daily_tables) - 1:
            # 마지막날 → 종료지점
            title = table_place_info["종료위치"]["name"]
            loc_info = table_place_info["종료위치"]
        else:
            # 중간날 → 숙소
            title = table_place_info["숙소"]["name"]
            loc_info = table_place_info["숙소"]

        new_end = (datetime.combine(datetime.today(), end_time) + timedelta(hours=1)).time()
        items_to_insert.append(ScheduleItem(title, end_time, new_end, "end" if idx == len(daily_tables) - 1 else "accommodation", loc_info))

        # 삽입 (앞, 뒤 순서 보장)
        schedule.insert(0, items_to_insert[0])
        schedule.append(items_to_insert[1])
    del table_place_info["숙소"]["name"]
    del table_place_info["시작위치"]["name"]
    del table_place_info["종료위치"]["name"]
    return daily_tables

tables = insert_initial_schedule_items_dynamic(tables, table_place_info)

for date, data in tables.items():
    print(f"{date} ({data['weekday']}) | From {data['start_location']} to {data['end_location']}")
    for item in data['schedule']:
        print(f"  {item.start.strftime('%H:%M')} - {item.end.strftime('%H:%M')} | {item.title}")
# Out:
# 2025-08-01 (Friday) | From 신도림역 to 라마다 서울 신도림 호텔
#   09:00 - 10:00 | 신도림역
#   10:00 - 12:00 | None
#   12:00 - 14:00 | None
#   14:00 - 16:00 | None
#   16:00 - 18:00 | None
#   18:00 - 20:00 | None
#   20:00 - 22:00 | None
#   22:00 - 23:00 | 라마다 서울 신도림 호텔
# 2025-08-02 (Saturday) | From 라마다 서울 신도림 호텔 to 라마다 서울 신도림 호텔
#   08:00 - 09:00 | 라마다 서울 신도림 호텔
#   09:00 - 11:00 | None
#   11:00 - 13:00 | None
#   13:00 - 15:00 | None
#   15:00 - 17:00 | None
#   17:00 - 19:00 | None
#   19:00 - 21:00 | None
#   21:00 - 23:00 | None
#   23:00 - 00:00 | 라마다 서울 신도림 호텔
# 2025-08-03 (Sunday) | From 라마다 서울 신도림 호텔 to 신도림역
#   08:00 - 09:00 | 라마다 서울 신도림 호텔
#   09:00 - 11:00 | None
#   11:00 - 13:00 | None
#   13:00 - 15:00 | None
#   15:00 - 17:00 | None
#   17:00 - 19:00 | None
#   19:00 - 21:00 | None
#   21:00 - 22:00 | 신도림역

# %%
# 명소 제약 조건 대입
def get_constraints(base_mode="명소 중심"):
    constraints = {
        "must_visit_attraction_every_minutes": 240,  # 4시간 : 마지막 명소 방문 후 일정 시간이 지나면 반드시 새로운 명소를 추천해야 한다는 제약
        "attraction_required": True, # 하루 일정에 명소가 반드시 포함되어야 하는지 여부

        "min_minutes_between_meals": 360,  # 6시간 : 식사 후 식사를 반드시 해야하는 제약 여부
        "require_meal_after_threshold": True, # 식사를 하지 않고 일정 시간이 지나면, 다음 일정으로 반드시 식사를 포함해야 한다는 조건
        "dont_eat_meal": 240, #식사 후 지나가야하는 시간 여부

        "department_store_required_interval": None, # 일정이 특정 시간(분 단위) 이상 지날 때마다 백화점이나 쇼핑몰을 꼭 일정에 넣어야 한다는 제약 조건

        "allow_multiple_cafes": False # 하루 일정에 카페(또는 유사 장소: 빵집 등)를 연속으로 포함하는 것을 허용할지 여부
    }
    # 추가 선택 옵션 반영
    if base_mode =="식사 중심": # 명소 필수 제거하고 식사 가게 제약을 3시간으로 감소
        constraints["attraction_required"] = False
        constraints["min_minutes_between_meals"] = 240

    if base_mode =="카페, 빵집 중심": # 식사 필수 조건 제거하고 명소 필수 제거, 카페연속 허용
        constraints["require_meal_after_threshold"] = False
        constraints["attraction_required"] = False
        constraints["allow_multiple_cafes"] = True

    if base_mode =="쇼핑 중심": # 명소조건 제거 및 백화점 개수 제한 해제
        constraints["department_store_required_interval"] = 180  # 3시간마다 쇼핑
        constraints["attraction_required"] = False

    return constraints

# 인덱스 기준 지난 최대 시간 반환
def get_elapsed_minutes_since_last_type(place_type, time_table, idx):
    """현재 인덱스 기준, 해당 타입(place_type)의 마지막 방문으로부터 경과한 시간(분)을 반환"""
    current_start = time_table[idx].start

    # 현재 이전 슬롯 중 해당 타입을 찾는다
    for i in range(idx - 1, -1, -1):
        if time_table[i].place_type == place_type:
            last_end = time_table[i].end
            return time_diff_minutes(last_end, current_start)

    # 해당 타입이 아예 없었으면 첫 일정 기준으로 계산
    first_time = time_table[0].start
    return time_diff_minutes(first_time, current_start)

# 타입 선택 함수
def select_allowed_types(time_table, base_mode, idx):
    allowed_types = ['tourist_attraction', 'cafe', 'restaurant', 'bakery', 'bar', 'shopping_mall']

    constraints = get_constraints(base_mode)

    if constraints["attraction_required"] == True:
        if get_elapsed_minutes_since_last_type('tourist_attraction', time_table, idx) >= constraints["must_visit_attraction_every_minutes"]:
            allowed_types = ['tourist_attraction']
            return allowed_types

    if constraints["require_meal_after_threshold"] == True:
        if get_elapsed_minutes_since_last_type('restaurant', time_table, idx)<=constraints["dont_eat_meal"]:
            allowed_types.remove("restaurant")
        if get_elapsed_minutes_since_last_type('restaurant', time_table, idx)>=constraints["min_minutes_between_meals"]:
            allowed_types = ['restaurant']
            return allowed_types

    if constraints["department_store_required_interval"] != None:
        if get_elapsed_minutes_since_last_type('shopping_mall', time_table, idx)<=constraints["department_store_required_interval"]:
            allowed_types = ['shopping_mall']
            return allowed_types

    if constraints["allow_multiple_cafes"] == False:
        if time_table[idx-1].place_type == "cafe" or time_table[idx-1].place_type == "bakery":
            for t in ["cafe", "bakery"]:
                allowed_types.remove(t)

    return allowed_types

import math

# 유클리드 기반 거리 계산 함수
def euclidean(lat1, lon1, lat2, lon2):
    return math.sqrt((lat1 - lat2) ** 2 + (lon1 - lon2) ** 2)

# 거리 계산 함수
def compute_distance(place1, place2):
    if not place1 or not place2:
        return float("inf")

    return ((place1['lat'] - place2['lat']) ** 2 + (place1['lng'] - place2['lng']) ** 2) ** 0.5

# %%
def parse_korean_time(text):
    try:
        if "오전" in text:
            return datetime.strptime(text, "오전 %I:%M").time()
        elif "오후" in text:
            hour = int(text.replace("오후 ", "").split(":")[0])
            minute = int(text.split(":")[1])
            if hour != 12:
                hour += 12
            return time(hour, minute)
        else:
            # 24시간제 예외 처리 (예: "10:00")
            return datetime.strptime(text.strip(), "%H:%M").time()
    except:
        return None

def is_place_open_during_slot(place, date_str, start_time, end_time):
    if place.get("business_status") != "OPERATIONAL":
        return False

    weekday = datetime.strptime(date_str, "%Y-%m-%d").weekday()
    weekday_kr = ["월요일", "화요일", "수요일", "목요일", "금요일", "토요일", "일요일"]
    target_day = weekday_kr[weekday]

    for text in place.get("weekday_text", []):
        if not text.startswith(target_day):
            continue

        # 24시간 영업 케이스 처리
        if "24시간" in text:
            return True

        try:
            time_range = text.split(": ", 1)[-1].split(" ~ ")
            open_time = parse_korean_time(time_range[0])
            close_time = parse_korean_time(time_range[1])
            if not open_time or not close_time:
                continue

            # 마감 시간이 자정 넘는 경우 처리
            if close_time < open_time:
                close_time = time(23, 59)

            if open_time <= start_time and end_time <= close_time:
                return True
        except:
            continue

    return False

def get_valid_candidates(all_places, allowed_types, date_str, slot):
    candidates = []

    for place in all_places:
        if place.get("in_timetable"):  # 이미 간 곳이면 제외
            continue
        if "호텔" in place.get("name", ""):  # 이름에 '호텔' 들어가면 제외
            continue
        if place['type'] not in allowed_types:
            continue
        if is_place_open_during_slot(place, date_str, slot.start, slot.end):
            candidates.append(place)

    return candidates

# %%
def get_user_params(user_id, filename="user_params.json"):
    try:
        with open(filename, "r", encoding="utf-8") as f:
            data = json.load(f)
        return data.get(user_id, None)  # 없으면 None 반환
    except FileNotFoundError:
        print(f"[오류] '{filename}' 파일을 찾을 수 없습니다.")
        return None
    except json.JSONDecodeError:
        print(f"[오류] '{filename}' 파일 형식이 잘못되었습니다.")
        return None

def compute_total_score(user_id, place, prev_location, ranges):
    if not prev_location:
        return -float("inf")

    # 사용자별 가중치 불러오기
    params = get_user_params(user_id)
    if params is None:
        # 기본값 적용
        params = {
            "w_dist": 0.5,
            "w_cluster": 0.4,
            "w_trust": 0.4,
            "w_nonhope": 0.3
        }

    # 거리 점수
    dist = compute_distance(prev_location, place)
    dist_score = 1 / (1 + dist)

    # 선호 유사도 (정규화 포함)
    raw_cluster_score = place.get("cluster_scores", 0.0)
    cluster_min = ranges["hope"]["min"]
    cluster_max = ranges["hope"]["max"]
    if cluster_max > cluster_min:
        cluster_score = (raw_cluster_score - cluster_min) / (cluster_max - cluster_min)
    else:
        cluster_score = 0.0

    # 비선호 점수 (정규화 포함)
    raw_nonhope_score = place.get("nonhope_score", 0.0)
    nonhope_min = ranges["nonhope"]["min"]
    nonhope_max = ranges["nonhope"]["max"]
    if nonhope_max > nonhope_min:
        nonhope_score = (raw_nonhope_score - nonhope_min) / (nonhope_max - nonhope_min)
    else:
        nonhope_score = 0.0

    # 신뢰도
    trust_score = place.get("trust_score", 0.0)

    # 사용자별 가중치 적용
    total_score = (
        params["w_dist"] * dist_score +
        params["w_cluster"] * cluster_score +
        params["w_trust"] * trust_score -
        params["w_nonhope"] * nonhope_score
    )

    return total_score


def compute_future_reward(user_id, schedule, current_idx, all_places, date_str, ranges, depth, base_mode):
    if depth == 0 or current_idx >= len(schedule):
        return 0

    current_slot = schedule[current_idx]

    if current_slot.title is not None:
        future_loc = current_slot.location_info
        prev_loc = None
        for i in range(current_idx - 1, -1, -1):
            if schedule[i].location_info:
                prev_loc = schedule[i].location_info
                break
        if prev_loc and future_loc:
            return compute_total_score(user_id, future_loc, prev_loc, ranges)
        else:
            return 0

    allowed_types = select_allowed_types(schedule, base_mode, current_idx)
    candidates = get_valid_candidates(all_places, allowed_types, date_str, current_slot)

    prev_loc = None
    for i in range(current_idx - 1, -1, -1):
        if schedule[i].location_info:
            prev_loc = schedule[i].location_info
            break

    top_candidates = sorted(candidates, key=lambda p: compute_distance(prev_loc, p))[:10]

    best_reward = -float("inf")
    for place in top_candidates:
        # 임시 삽입
        schedule[current_idx].title = place["name"]
        schedule[current_idx].place_type = place["type"]
        schedule[current_idx].location_info = {
            "lat": place["lat"],
            "lng": place["lng"]
        }
        place["in_timetable"] = True

        immediate = compute_total_score(user_id, place, prev_loc, ranges)
        future = compute_future_reward(user_id, schedule, current_idx + 1, all_places, date_str, ranges, depth - 1, base_mode)
        total = immediate + future

        if total > best_reward:
            best_reward = total

        # 롤백
        schedule[current_idx].title = None
        schedule[current_idx].place_type = None
        schedule[current_idx].location_info = None
        place["in_timetable"] = False

    return best_reward

def dqn_fill_schedule(user_id, tables, all_places, base_mode="명소 중심"):
    ranges = get_score_ranges(all_places)  # cluster, nonhope 포함
    for date_str, info in tables.items():
        schedule = info["schedule"]
        for idx, slot in enumerate(schedule):
            if slot.title is not None:
                continue

            allowed_types = select_allowed_types(schedule, base_mode, idx)
            if not allowed_types:
                continue

            candidates = get_valid_candidates(all_places, allowed_types, date_str, slot)
            if not candidates:
                continue

            prev_loc = None
            for i in range(idx - 1, -1, -1):
                if schedule[i].location_info:
                    prev_loc = schedule[i].location_info
                    break

            if prev_loc is None:
                continue

            top_candidates = sorted(candidates, key=lambda p: compute_distance(prev_loc, p))[:10]
            if not top_candidates:
                continue

            best_score = -float("inf")
            best_place = None

            for place in top_candidates:
                immediate = compute_total_score(user_id, place, prev_loc, ranges)
                future = compute_future_reward(
                    user_id, schedule, idx + 1, all_places, date_str, ranges, depth=2, base_mode=base_mode
                )
                total = immediate + future

                if total > best_score:
                    best_score = total
                    best_place = place

            if best_place:
                schedule[idx].title = best_place["name"]
                schedule[idx].place_type = best_place["type"]
                schedule[idx].location_info = {
                    "name": best_place["name"],
                    "lat": best_place["lat"],
                    "lng": best_place["lng"]
                }
                best_place["in_timetable"] = True

    return tables

# %%
def init_user_profile(user_id, default_weights=None):
    if default_weights is None:
        default_weights = {
            "w_dist": 0.5,
            "w_cluster": 0.4,
            "w_trust": 0.4,
            "w_nonhope": 0.3
        }
    return {user_id: default_weights.copy()}

def save_user_params_to_json(user_params, filename="user_params.json"):
    # numpy 배열은 json으로 바로 저장할 수 없으니 list로 변환
    serializable_params = {}
    for user_id, params in user_params.items():
        serializable_params[user_id] = {
            key: value.tolist() if isinstance(value, np.ndarray) else value
            for key, value in params.items()
        }

    with open(filename, "w", encoding="utf-8") as f:
        json.dump(serializable_params, f, indent=4, ensure_ascii=False)

# %%
def save_travel_log(user_id, route_places, user_rating, title="나의 여행", filename="travel_logs.json"):
    import json
    from datetime import datetime

    # 파일 읽기
    try:
        with open(filename, "r", encoding="utf-8") as f:
            content = f.read().strip()
            data = json.loads(content) if content else {}
    except FileNotFoundError:
        data = {}

    # 사용자별 로그 초기화
    if user_id not in data:
        data[user_id] = []

    # 제목 중복 체크
    existing_titles = {log.get("title", "") for log in data[user_id]}
    base_title = title
    suffix = 1
    while title in existing_titles:
        suffix += 1
        title = f"{base_title} ({suffix})"

    # 일정 구성
    table_data = {}
    for date_str, info in route_places.items():
        # 요일 정보 추가
        weekday = datetime.strptime(date_str, "%Y-%m-%d").strftime("%A") # 날짜 문자열에서 요일 추출

        table_data[date_str] = {
            "weekday": weekday, # 요일 정보 저장
            "start_location": info["start_location"],
            "end_location": info["end_location"],
            "schedule": [
                {
                    "title": travel_place.title,
                    "start": travel_place.start.strftime("%H:%M"),
                    "end": travel_place.end.strftime("%H:%M"),
                    "type": travel_place.place_type,
                    "location_info": {
                        "lat": travel_place.location_info["lat"],
                        "lng": travel_place.location_info["lng"]
                    },
                    "rating": None
                }
                for travel_place in info["schedule"]
            ]
        }

    # 저장할 객체 구성
    travel_log = {
        "title": title,
        "table": table_data,
        "rating": user_rating
    }

    # 추가 및 저장
    data[user_id].append(travel_log)
    with open(filename, "w", encoding="utf-8") as f:
        json.dump(data, f, indent=2, ensure_ascii=False)

# %%
user_id = "user_001"

user_params = {}
user_params.update(init_user_profile(user_id))

save_user_params_to_json(user_params)

table_place_info, tables = create_empty_daily_tables(
    API_KEY,
    start_date_str="2025-08-01",
    end_date_str="2025-08-03",
    first_day_start_time=time(10, 0),
    last_day_end_time=time(21, 0),
    start_location="신도림역",
    final_end_location="신도림역",
    accommodation_location="신도림 숙소"
)

tables = insert_initial_schedule_items_dynamic(tables, table_place_info)

for place in all_places:
    place["in_timetable"] = False

tables = dqn_fill_schedule(
    user_id,
    tables,
    all_places
)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-4177039418.py in <cell line: 0>()
#      20
#      21 for place in all_places:
# ---> 22     place["in_timetable"] = False
#      23
#      24 tables = dqn_fill_schedule(
#
# TypeError: 'str' object does not support item assignment

# %%
def print_schedule_tables(tables):
    for date_str, info in tables.items():
        print(f"\n{date_str} | From {info['start_location']} to {info['end_location']}")
        for item in info["schedule"]:
            title = item.title if item.title else "None"
            print(f"  {item.start.strftime('%H:%M')} - {item.end.strftime('%H:%M')} | {title}")

print_schedule_tables(tables)
# Out:
# 2025-08-01 | From 신도림역 to 라마다 서울 신도림 호텔
#   09:00 - 10:00 | 신도림역
#   10:00 - 12:00 | None
#   12:00 - 14:00 | None
#   14:00 - 16:00 | None
#   16:00 - 18:00 | None
#   18:00 - 20:00 | None
#   20:00 - 22:00 | None
#   22:00 - 23:00 | 라마다 서울 신도림 호텔
#
# 2025-08-02 | From 라마다 서울 신도림 호텔 to 라마다 서울 신도림 호텔
#   08:00 - 09:00 | 라마다 서울 신도림 호텔
#   09:00 - 11:00 | None
#   11:00 - 13:00 | None
#   13:00 - 15:00 | None
#   15:00 - 17:00 | None
#   17:00 - 19:00 | None
#   19:00 - 21:00 | None
#   21:00 - 23:00 | None
#   23:00 - 00:00 | 라마다 서울 신도림 호텔
#
# 2025-08-03 | From 라마다 서울 신도림 호텔 to 신도림역
#   08:00 - 09:00 | 라마다 서울 신도림 호텔
#   09:00 - 11:00 | None
#   11:00 - 13:00 | None
#   13:00 - 15:00 | None
#   15:00 - 17:00 | None
#   17:00 - 19:00 | None
#   19:00 - 21:00 | None
#   21:00 - 22:00 | 신도림역

# %%
save_travel_log("user_001",tables,3)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-1646582361.py in <cell line: 0>()
# ----> 1 save_travel_log("user_001",tables,3)
#
# /tmp/ipython-input-2560344455.py in save_travel_log(user_id, route_places, user_rating, title, filename)
#      33             "start_location": info["start_location"],
#      34             "end_location": info["end_location"],
# ---> 35             "schedule": [
#      36                 {
#      37                     "title": travel_place.title,
#
# /tmp/ipython-input-2560344455.py in <listcomp>(.0)
#      40                     "type": travel_place.place_type,
#      41                     "location_info": {
# ---> 42                         "lat": travel_place.location_info["lat"],
#      43                         "lng": travel_place.location_info["lng"]
#      44                     },
#
# TypeError: 'NoneType' object is not subscriptable

# %%
def rate_user_trip(user_id, title, filename="travel_logs.json"):
    try:
        with open(filename, "r", encoding="utf-8") as f:
            data = json.load(f)
    except FileNotFoundError:
        print("파일이 존재하지 않습니다.")
        return

    user_trips = data.get(user_id)
    if not user_trips:
        print(f"{user_id}에 해당하는 여행 정보가 없습니다.")
        return

    # title에 해당하는 여행 찾기
    trip = next((t for t in user_trips if t["title"] == title), None)
    if not trip:
        print(f"'{title}' 제목의 여행을 찾을 수 없습니다.")
        return

    print(f"\n'{title}' 일정의 여행을 평가합니다.\n")

    # 날짜별로 순차 평가
    for date, day_info in trip["table"].items():
        schedule = day_info["schedule"]
        print(f"날짜: {date}")

        # 첫 번째와 마지막 슬롯 제외
        for i, slot in enumerate(schedule):
            if i == 0 or i == len(schedule) - 1:
                continue

            slot_title = slot.get("title")
            if not slot_title or slot_title in ["", "출발지", "도착지"]:
                continue

            print(f" - 장소: {slot_title} ({slot['start']} ~ {slot['end']})")
            while True:
                try:
                    score = float(input("   ➤ 이 장소의 별점을 입력하세요 (0~5): "))
                    if 0.0 <= score <= 5.0:
                        slot["rating"] = round(score, 1)
                        break
                    else:
                        print("   0부터 5 사이의 숫자를 입력하세요.")
                except ValueError:
                    print("   숫자를 입력해주세요.")

    # 저장
    with open(filename, "w", encoding="utf-8") as f:
        json.dump(data, f, ensure_ascii=False, indent=2)
    print("\n평가가 완료되어 저장되었습니다.")

# %%
rate_user_trip(user_id, "나의 여행")
# Out:
# '나의 여행' 일정의 여행을 평가합니다.
#
# 날짜: 2025-08-01
#  - 장소: 참새어린이공원 (10:00 ~ 12:00)
#    ➤ 이 장소의 별점을 입력하세요 (0~5): 4
#  - 장소: 파스쿠찌 보라매공원점 (12:00 ~ 14:00)
#    ➤ 이 장소의 별점을 입력하세요 (0~5): 3
#  - 장소: 막내회센타 (14:00 ~ 16:00)
#    ➤ 이 장소의 별점을 입력하세요 (0~5): 2
#  - 장소: 국립중앙박물관 (16:00 ~ 18:00)
#    ➤ 이 장소의 별점을 입력하세요 (0~5): 1
#  - 장소: N서울타워 (18:00 ~ 20:00)
#    ➤ 이 장소의 별점을 입력하세요 (0~5): 4
#  - 장소: 광화문광장 (20:00 ~ 22:00)
#    ➤ 이 장소의 별점을 입력하세요 (0~5): 3
# 날짜: 2025-08-02
#  - 장소: 투썸플레이스 가산디지털점 (09:00 ~ 11:00)
#    ➤ 이 장소의 별점을 입력하세요 (0~5): 4
#  - 장소: 부천원미공원 (11:00 ~ 13:00)
#    ➤ 이 장소의 별점을 입력하세요 (0~5): 4
#  - 장소: 도당근린공원 백만송이장미원 (13:00 ~ 15:00)
#    ➤ 이 장소의 별점을 입력하세요 (0~5): 4
#  - 장소: 삿뽀로 목동점 (15:00 ~ 17:00)
#    ➤ 이 장소의 별점을 입력하세요 (0~5):
#    숫자를 입력해주세요.
#    ➤ 이 장소의 별점을 입력하세요 (0~5):
#    숫자를 입력해주세요.
#    ➤ 이 장소의 별점을 입력하세요 (0~5):
#    숫자를 입력해주세요.
#    ➤ 이 장소의 별점을 입력하세요 (0~5):
#    숫자를 입력해주세요.
#    ➤ 이 장소의 별점을 입력하세요 (0~5): 4
#  - 장소: 계남제1근린공원 (17:00 ~ 19:00)
#    ➤ 이 장소의 별점을 입력하세요 (0~5): 4
#  - 장소: 뚜레쥬르 양천캐슬점(신월4동) (19:00 ~ 21:00)
#    ➤ 이 장소의 별점을 입력하세요 (0~5): 4
#  - 장소: 체육공원 (21:00 ~ 23:00)
#    ➤ 이 장소의 별점을 입력하세요 (0~5): 4
# 날짜: 2025-08-03
#  - 장소: 뚜레쥬르 대방역점 (09:00 ~ 11:00)
#    ➤ 이 장소의 별점을 입력하세요 (0~5): 4
#  - 장소: 전쟁기념관 (11:00 ~ 13:00)
#    ➤ 이 장소의 별점을 입력하세요 (0~5): 4
#  - 장소: 명동대성당 (13:00 ~ 15:00)
#    ➤ 이 장소의 별점을 입력하세요 (0~5): 4
#  - 장소: 한일관 타임스퀘어점 (15:00 ~ 17:00)
#    ➤ 이 장소의 별점을 입력하세요 (0~5): 4
#  - 장소: 커피빈 홍대역점 (17:00 ~ 19:00)
#    ➤ 이 장소의 별점을 입력하세요 (0~5): 4
#  - 장소: 덕수궁 (19:00 ~ 21:00)
#    ➤ 이 장소의 별점을 입력하세요 (0~5): 4
#
# 평가가 완료되어 저장되었습니다.

# %%
keyword_hope = ["루프탑","야경","전망대","고층건물","한강 뷰"]
keyword_nonhope = ["벌레","먼지","혼잡","더러움","공원"]
keyword_hope = [clean_keyword(r) for r in keyword_hope if r]
keyword_nonhope = [clean_keyword(r) for r in keyword_nonhope if r]

# %%
import matplotlib.pyplot as plt

def plot_schedule_path(tables):
    plt.figure(figsize=(10, 8))

    colors = ['red', 'blue', 'green']  # 날짜별 경로 색상

    for idx, (date_str, info) in enumerate(tables.items()):
        schedule = info["schedule"]
        color = colors[idx % len(colors)]

        for i, item in enumerate(schedule):
            loc = item.location_info
            if not loc:
                continue

            lat = loc["lat"]
            lng = loc["lng"]
            place_type = item.place_type or ""

            # 마커 모양 결정
            if place_type in ["restaurant", "bar"]:
                marker = "*"
            elif place_type in ["cafe", "bakery"]:
                marker = "^"
            else:
                marker = "o"

            plt.plot(lng, lat, marker=marker, color=color)

        # 라인으로 연결
        lats = [item.location_info["lat"] for item in schedule if item.location_info]
        lngs = [item.location_info["lng"] for item in schedule if item.location_info]
        if lats and lngs:
            plt.plot(lngs, lats, linestyle='-', color=color, alpha=0.5)

    plt.xlabel("Longitude")
    plt.ylabel("Latitude")
    plt.legend()
    plt.grid(True)
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ## 핵심 함수 정리 (Google API 시각화 기능 포함)
#
# 아래 셀들은 Google Maps Directions API를 사용하여 여행 경로를 시각화하는 데 필요한 핵심 함수들입니다.
#
# 1.  `get_google_route`: Google Maps Directions API를 호출하여 경로 데이터를 가져옵니다.
# 2.  `load_travel_log`: JSON 파일에서 여행 기록을 불러옵니다.
# 3.  `visualize_full_route`: 전체 여행 경로를 하나의 지도에 시각화합니다.
# 4.  `visualize_daily_routes`: 각 날짜별 여행 경로를 별도의 지도에 시각화합니다.

# %%
# 1. Google Maps Directions API 호출 함수 (get_google_route)

import requests
import polyline
import folium
import json
from datetime import time, datetime
import numpy as np # numpy가 필요한 다른 함수들을 위해 남겨둡니다.

# GOOGLE_API_KEY 변수는 별도의 셀에서 정의하고 값을 할당해야 합니다.
# 예: GOOGLE_API_KEY = "YOUR_GOOGLE_API_KEY"

# ScheduleItem 클래스 정의 (JSON 데이터 로딩 시 필요) - 이동 수단 필드 포함
class ScheduleItem:
    def __init__(self, title, start, end, place_type, location_info=None, travel_mode_to_next=None):
        self.title = title
        # 문자열 시간을 time 객체로 변환
        if isinstance(start, str):
            self.start = datetime.strptime(start, "%H:%M").time()
        else:
            self.start = start
        if isinstance(end, str):
            self.end = datetime.strptime(end, "%H:%M").time()
        else:
            self.end = end
        self.place_type = place_type
        self.location_info = location_info
        self.travel_mode_to_next = travel_mode_to_next # 다음 이동 수단 필드 추가

def get_google_route(start_lat, start_lng, end_lat, end_lng, travel_mode):
    """
    Calls the Google Maps Directions API with a specified travel mode.

    Args:
        start_lat (float): Latitude of the origin.
        start_lng (float): Longitude of the origin.
        end_lat (float): Latitude of the destination.
        end_lng (float): Longitude of the destination.
        travel_mode (str): The mode of travel ('WALKING', 'DRIVING', 'TRANSIT', 'BICYCLING').

    Returns:
        tuple: A tuple containing the decoded polyline (list of lat/lng pairs)
               and the total distance (in meters), or (None, None) if no route is found.
    """
    url = "https://maps.googleapis.com/maps/api/directions/json"
    params = {
        "origin": f"{start_lat},{start_lng}",
        "destination": f"{end_lat},{end_lng}",
        "mode": travel_mode.lower(),  # Google API mode should be lowercase
        "key": GOOGLE_API_KEY # Assume GOOGLE_API_KEY is defined by the user
    }

    try:
        response = requests.get(url, params=params)
        res = response.json()

        if res.get("status") != "OK" or not res.get("routes"):
            # print(f"Google Directions API 오류 ({travel_mode}): {res.get('status')}") # 오류 메시지 출력은 시각화 함수에서 하도록 변경
            # if res.get("error_message"):
            #      print(f"오류 메시지: {res['error_message']}")
            return None, None

        route = res["routes"][0]
        overview_polyline = route["overview_polyline"]["points"]
        distance = route["legs"][0]["distance"]["value"]  # Distance in meters

        decoded_polyline = polyline.decode(overview_polyline)

        return decoded_polyline, distance

    except requests.exceptions.RequestException as e:
        print(f"API 요청 중 오류 발생 ({travel_mode}): {e}")
        return None, None
    except Exception as e:
        print(f"경로 처리 중 오류 발생 ({travel_mode}): {e}")
        return None, None

# %%
# 2. 여행 기록 불러오기 함수 (load_travel_log)

# ScheduleItem 클래스는 위에 정의되어 있다고 가정합니다 (셀 ID a2c0f6c2 또는 c1379152 등).
# get_google_route 함수도 위에 정의되어 있다고 가정합니다 (셀 ID a7b57498 등).

def load_travel_log(user_id, title, filename="travel_logs.json"):
    try:
        with open(filename, "r", encoding="utf-8") as f:
            content = f.read().strip()
            data = json.loads(content) if content else {}
    except FileNotFoundError:
        print("파일이 존재하지 않습니다.")
        return None

    user_trips = data.get(user_id)
    if not user_trips:
        print(f"{user_id}에 해당하는 여행 정보가 없습니다.")
        return None

    trip = next((t for t in user_trips if t["title"] == title), None)
    if not trip:
        print(f"'{title}' 제목의 여행을 찾을 수 없습니다.")
        return None

    # JSON 데이터를 ScheduleItem 객체로 변환
    loaded_tables = {}
    for date_str, day_info in trip["table"].items():
        loaded_schedule = []
        for slot_data in day_info["schedule"]:
            loaded_schedule.append(ScheduleItem(
                slot_data.get("title"),
                slot_data.get("start"),
                slot_data.get("end"),
                slot_data.get("type"),
                slot_data.get("location_info"),
                slot_data.get("travel_mode_to_next") # Load the new attribute
            ))
        loaded_tables[date_str] = {
            "weekday": day_info.get('weekday', '알 수 없는 요일'),
            "start_location": day_info["start_location"],
            # 수정: day_location 함수 호출 제거. 저장된 end_location 값을 그대로 사용.
            "end_location": day_info["end_location"],
            "schedule": loaded_schedule
        }
    return loaded_tables

# %%
# 3. 전체 여행 경로 시각화 함수 (visualize_full_route) - 사용자 선택 이동 수단 반영

def visualize_full_route(tables):
    all_coords = []
    map_center = None

    # 지도 생성 (첫 장소 기준)
    # 모든 장소의 좌표를 먼저 수집하여 지도의 중심을 계산할 수도 있지만, 여기서는 단순하게 첫 장소를 중심으로 설정
    first_loc = None
    for date_str, info in tables.items():
        for item in info["schedule"]:
            if item.location_info:
                first_loc = item.location_info
                break
        if first_loc:
            break

    if not first_loc:
        print("시각화할 장소 정보가 없습니다.")
        return None

    m = folium.Map(location=[first_loc["lat"], first_loc["lng"]], zoom_start=12)

    colors = ['red', 'blue', 'green', 'purple', 'orange', 'darkred', 'lightred', 'beige', 'darkblue', 'darkgreen', 'cadetblue', 'darkpurple', 'white', 'pink', 'lightblue', 'lightgreen', 'gray', 'black', 'lightgray'] # 날짜별 경로 색상 팔레트

    for idx, (date_str, info) in enumerate(tables.items()):
        schedule = info["schedule"]
        day_coords = []
        day_color = colors[idx % len(colors)] # 날짜별 색상 선택
        day_number = idx + 1 # 1일차, 2일차 ...

        # 그날의 유효한 장소만 필터링 (방문 순서 계산용)
        valid_schedule_items = [item for item in schedule if item.location_info]

        for i, item in enumerate(schedule):
            loc = item.location_info
            if loc:
                lat, lng = loc["lat"], loc["lng"]
                all_coords.append((lat, lng))
                day_coords.append((lat, lng))

                # 현재 장소가 그날의 유효한 장소 목록에서 몇 번째인지 찾기
                try:
                    visit_order_today = valid_schedule_items.index(item) + 1 if item in valid_schedule_items else None
                except ValueError:
                     visit_order_today = None


                # 팝업 텍스트 생성 (날짜 및 그날의 순서 포함)
                popup_text = f"<b>{day_number}일차</b>"
                if visit_order_today is not None:
                     popup_text += f" - <b>{visit_order_today}번째 방문</b>"

                popup_text += f"<br>{item.title}<br>({item.start.strftime('%H:%M')}~{item.end.strftime('%H:%M')})"
                # 사용자가 선택한 다음 이동 수단 정보 추가 (팝업에 표시)
                if hasattr(item, 'travel_mode_to_next') and item.travel_mode_to_next:
                    popup_text += f"<br>다음 이동: {item.travel_mode_to_next}"


                # 마커 추가 (장소 이름 포함) - 날짜별 색상 사용
                folium.Marker(
                    [lat, lng],
                    popup=popup_text,
                    icon=folium.Icon(color=day_color)
                ).add_to(m)


        # 하루 일정이 있으면 경로 시각화
        if len(day_coords) > 1:
            for i in range(len(day_coords) - 1):
                start_item = schedule[i]
                end_item = schedule[i+1]

                # Check if both start and end items have location info before attempting route
                if not start_item.location_info or not end_item.location_info:
                     # print(f"Skipping route for segment without location info: {start_item.title} to {end_item.title}")
                     continue # Skip this segment if location info is missing

                start_loc = start_item.location_info
                end_loc = end_item.location_info


                # 해당 구간의 이동 수단 가져오기 (start_item의 travel_mode_to_next 사용)
                # 만약 설정되지 않았다면 기본값 'WALKING' 사용
                segment_travel_mode = getattr(start_item, 'travel_mode_to_next', 'WALKING')
                if segment_travel_mode is None:
                    segment_travel_mode = 'WALKING'


                # Google Directions API 호출 (사용자 선택 이동 수단 적용)
                decoded_polyline, distance = get_google_route(start_loc["lat"], start_loc["lng"], end_loc["lat"], end_loc["lng"], segment_travel_mode)

                if decoded_polyline:
                    # API 경로 라인 추가 (날짜별 색상 적용)
                    folium.PolyLine(locations=decoded_polyline, color=day_color, weight=2.5, opacity=0.8).add_to(m)
                    # Optional: Print distance and mode
                    # print(f"{start_item.title}에서 {end_item.title}까지 ({segment_travel_mode}) 거리: {distance/1000:.2f} km")
                else:
                    # API 실패 시 직선 연결 (점선)
                    print(f"경로 API 실패 ({segment_travel_mode}): {start_item.title}에서 {end_item.title}까지 직선으로 연결합니다.")
                    folium.PolyLine(locations=[[start_loc["lat"], start_loc["lng"]], [end_loc["lat"], end_loc["lng"]]], color=day_color, weight=2.5, opacity=0.8, dash_array='5, 5').add_to(m)


    return m

# %%
# 4. 각 날짜별 여행 경로 시각화 함수 (visualize_daily_routes) - 사용자 선택 이동 수단 반영 (준비 단계)

def visualize_daily_routes(tables):
    """
    각 날짜별 여행 경로를 별도의 지도에 시각화합니다.
    마커에 방문 순서를 표시하고, 첫/마지막 장소 색상을 구분합니다.
    (이 함수는 주로 사용자에게 각 구간을 보여주고 이동 수단을 선택받는 준비 단계에서 사용될 수 있습니다.)
    """
    colors = ['red', 'blue', 'green', 'purple', 'orange', 'darkred', 'lightred', 'beige', 'darkblue', 'darkgreen', 'cadetblue', 'darkpurple', 'white', 'pink', 'lightblue', 'lightgreen', 'gray', 'black', 'lightgray'] # 날짜별 경로 색상 팔레트

    for idx, (date_str, info) in enumerate(tables.items()):
        schedule = info["schedule"]
        day_coords = []
        day_color = colors[idx % len(colors)] # 날짜별 색상 선택

        weekday = info.get('weekday', '알 수 없는 요일')
        print(f"\n--- {date_str} ({weekday}) 여행 경로 ---")

        first_loc_of_day = None
        for item in schedule:
            if item.location_info:
                first_loc_of_day = item.location_info
                break

        if not first_loc_of_day:
            print("해당 날짜의 시각화할 장소 정보가 없습니다.")
            continue

        m_day = folium.Map(location=[first_loc_of_day["lat"], first_loc_of_day["lng"]], zoom_start=12)

        valid_schedule_items = [item for item in schedule if item.location_info]

        for i, item in enumerate(valid_schedule_items):
            loc = item.location_info
            lat, lng = loc["lat"], loc["lng"]
            day_coords.append((lat, lng))

            display_order = i + 1
            popup_text = f"<b>방문 순서 #{display_order}</b><br>{item.title}<br>({item.start.strftime('%H:%M')}~{item.end.strftime('%H:%M')})"
            # 사용자가 선택한 다음 이동 수단 정보 추가 (팝업에 표시)
            if hasattr(item, 'travel_mode_to_next') and item.travel_mode_to_next:
                popup_text += f"<br>다음 이동: {item.travel_mode_to_next}"


            if i == 0:
                marker_color = 'green'
                icon_type = 'play'
            elif i == len(valid_schedule_items) - 1:
                marker_color = 'red'
                icon_type = 'stop'
            else:
                marker_color = day_color
                icon_type = 'info'

            folium.Marker(
                [lat, lng],
                popup=popup_text,
                icon=folium.Icon(color=marker_color, icon=icon_type, prefix='fa')
            ).add_to(m_day)


        if len(day_coords) > 1:
            for i in range(len(day_coords) - 1):
                start_item = schedule[i]
                end_item = schedule[i+1]

                # Check if both start and end items have location info before attempting route
                if not start_item.location_info or not end_item.location_info:
                     continue

                start_loc = start_item.location_info
                end_loc = end_item.location_info

                # 해당 구간의 이동 수단 가져오기 (start_item의 travel_mode_to_next 사용)
                # 만약 설정되지 않았다면 기본값 'WALKING' 사용
                segment_travel_mode = getattr(start_item, 'travel_mode_to_next', 'WALKING')
                if segment_travel_mode is None:
                    segment_travel_mode = 'WALKING'

                # Google Directions API 호출 (사용자 선택 이동 수단 적용)
                decoded_polyline, distance = get_google_route(start_loc["lat"], start_loc["lng"], end_loc["lat"], end_loc["lng"], segment_travel_mode)

                if decoded_polyline:
                    folium.PolyLine(locations=decoded_polyline, color=day_color, weight=2.5, opacity=0.8).add_to(m_day)
                else:
                    print(f"경로 API 실패 ({segment_travel_mode}): {start_item.title}에서 {end_item.title}까지 직선으로 연결합니다.")
                    folium.PolyLine(locations=[[start_loc["lat"], start_loc["lng"]], [end_loc["lat"], end_loc["lng"]]], color=day_color, weight=2.5, opacity=0.8, dash_array='5, 5').add_to(m_day)

        display(m_day)

# %% [markdown]
# ## 여행 기록 불러오기, 이동 수단 선택 및 시각화 실행
#
# 아래 셀들을 순서대로 실행하여 저장된 여행 기록을 불러오고, 구간별 이동 수단을 선택한 후, Google Maps Directions API를 사용하여 지도에 시각화할 수 있습니다.
#
# **주의:** 시각화가 제대로 되려면 `GOOGLE_API_KEY`에 유효한 Google Maps API 키가 설정되어 있고, Directions API가 활성화되어 있어야 합니다.

# %%
# 1. Google API 키 설정 확인/입력

# 여기에 구글맵 Directions API 키를 입력하세요.
# Google Cloud Platform에서 API 키를 생성하고, Directions API가 활성화되어 있는지 확인하세요.
# 이미 설정된 셀이 있다면 그 셀을 사용하셔도 됩니다. 여기서는 명확성을 위해 다시 포함합니다.
GOOGLE_API_KEY = "AIzaSyDlY8HKdl2TiRRZq6VY8M3RWulrWUJ6vBk" # 이 부분을 발급받으신 실제 Google API 키로 바꾸세요.

# 참고: Colab Secrets 기능을 사용하여 API 키를 안전하게 관리하는 것을 권장합니다.
# 좌측 패널의 '🔑' 아이콘을 클릭하여 Secrets에 GOOGLE_API_KEY를 추가하고 사용하세요.
# from google.colab import userdata
# GOOGLE_API_KEY = userdata.get('GOOGLE_API_KEY')

print("Google API 키 설정 셀 준비 완료. 키 값을 입력하고 실행해주세요.")
# Out:
# Google API 키 설정 셀 준비 완료. 키 값을 입력하고 실행해주세요.

# %%
# 2. 여행 기록 불러오기

# 예시: user_001의 여행 기록 불러오기
user_id = "user_001"
# --- 중요: 아래 travel_title 변수에 travel_logs.json 파일에 저장된
#            실제 여행 기록의 정확한 제목을 입력해주세요. ---
travel_title = "나의 여행" # 이 부분을 실제 제목으로 수정하세요.
# -------------------------------------------------------------

# load_travel_log 함수 (위에 정의된 함수 사용)
# GOOGLE_API_KEY가 설정되어 있어야 합니다.

print("--- 여행 기록 불러오기 ---")
tables_from_log = load_travel_log(user_id, travel_title)

if tables_from_log:
    print(f"'{travel_title}' 여행 기록을 성공적으로 불러왔습니다.")
else:
    print(f"'{travel_title}' 제목의 여행 기록 데이터를 불러오지 못했습니다. travel_title을 확인해주세요.")
# Out:
# --- 여행 기록 불러오기 ---
# '나의 여행' 여행 기록을 성공적으로 불러왔습니다.

# %%
# 3. 이동 수단 선택 (사용자 인터랙션 필요)

# travel_logs_from_log 변수가 바로 위 셀 실행 시 성공적으로 로드되었다고 가정합니다.
# select_travel_modes 함수 (위에 정의된 함수 사용)

if 'tables_from_log' in locals() and tables_from_log:
    print("\n--- 이동 수단 선택 ---")
    # 이 단계는 사용자 입력이 필요하며, 실행 후 tables_with_modes 변수에 결과가 저장됩니다.
    tables_with_modes = select_travel_modes(tables_from_log)
else:
    print("여행 기록 데이터가 로드되지 않았습니다. 이동 수단을 선택할 수 없습니다.")
# Out:
# --- 이동 수단 선택 ---
#
# --- 여행 구간별 이동 수단 선택 ---
#
# 날짜: 2025-08-01 (알 수 없는 요일)
#
# 경로: '신도림역' 에서 '참새어린이공원' 까지
# 선택 가능한 이동 수단: WALKING, DRIVING, TRANSIT, BICYCLING
# 이동 수단을 선택하세요: WALKING
# '신도림역' 에서 '참새어린이공원' 까지 이동 수단: WALKING 으로 설정되었습니다.
#
# 경로: '참새어린이공원' 에서 '파스쿠찌 보라매공원점' 까지
# 선택 가능한 이동 수단: WALKING, DRIVING, TRANSIT, BICYCLING
# 이동 수단을 선택하세요: DRIVING
# '참새어린이공원' 에서 '파스쿠찌 보라매공원점' 까지 이동 수단: DRIVING 으로 설정되었습니다.
#
# 경로: '파스쿠찌 보라매공원점' 에서 '막내회센타' 까지
# 선택 가능한 이동 수단: WALKING, DRIVING, TRANSIT, BICYCLING
# 이동 수단을 선택하세요: DRIVING
# '파스쿠찌 보라매공원점' 에서 '막내회센타' 까지 이동 수단: DRIVING 으로 설정되었습니다.
#
# 경로: '막내회센타' 에서 '국립중앙박물관' 까지
# 선택 가능한 이동 수단: WALKING, DRIVING, TRANSIT, BICYCLING
# 이동 수단을 선택하세요: TRANSIT
# '막내회센타' 에서 '국립중앙박물관' 까지 이동 수단: TRANSIT 으로 설정되었습니다.
#
# 경로: '국립중앙박물관' 에서 'N서울타워' 까지
# 선택 가능한 이동 수단: WALKING, DRIVING, TRANSIT, BICYCLING
# 이동 수단을 선택하세요: BICYCLING
# '국립중앙박물관' 에서 'N서울타워' 까지 이동 수단: BICYCLING 으로 설정되었습니다.
#
# 경로: 'N서울타워' 에서 '광화문광장' 까지
# 선택 가능한 이동 수단: WALKING, DRIVING, TRANSIT, BICYCLING
# 이동 수단을 선택하세요: DRIVING
# 'N서울타워' 에서 '광화문광장' 까지 이동 수단: DRIVING 으로 설정되었습니다.
#
# 경로: '광화문광장' 에서 '라마다 서울 신도림 호텔' 까지
# 선택 가능한 이동 수단: WALKING, DRIVING, TRANSIT, BICYCLING
# 이동 수단을 선택하세요: WALKING
# '광화문광장' 에서 '라마다 서울 신도림 호텔' 까지 이동 수단: WALKING 으로 설정되었습니다.
#
# --- 업데이트된 일정 ---
#   09:00 - 10:00 | 신도림역 | 다음 이동 수단: WALKING
#   10:00 - 12:00 | 참새어린이공원 | 다음 이동 수단: DRIVING
#   12:00 - 14:00 | 파스쿠찌 보라매공원점 | 다음 이동 수단: DRIVING
#   14:00 - 16:00 | 막내회센타 | 다음 이동 수단: TRANSIT
#   16:00 - 18:00 | 국립중앙박물관 | 다음 이동 수단: BICYCLING
#   18:00 - 20:00 | N서울타워 | 다음 이동 수단: DRIVING
#   20:00 - 22:00 | 광화문광장 | 다음 이동 수단: WALKING
#   22:00 - 23:00 | 라마다 서울 신도림 호텔 | 다음 이동 수단: 미정
#
# 날짜: 2025-08-02 (알 수 없는 요일)
#
# 경로: '라마다 서울 신도림 호텔' 에서 '투썸플레이스 가산디지털점' 까지
# 선택 가능한 이동 수단: WALKING, DRIVING, TRANSIT, BICYCLING
# 이동 수단을 선택하세요: WALKING
# '라마다 서울 신도림 호텔' 에서 '투썸플레이스 가산디지털점' 까지 이동 수단: WALKING 으로 설정되었습니다.
#
# 경로: '투썸플레이스 가산디지털점' 에서 '부천원미공원' 까지
# 선택 가능한 이동 수단: WALKING, DRIVING, TRANSIT, BICYCLING
# 이동 수단을 선택하세요: WALKING
# '투썸플레이스 가산디지털점' 에서 '부천원미공원' 까지 이동 수단: WALKING 으로 설정되었습니다.
#
# 경로: '부천원미공원' 에서 '도당근린공원 백만송이장미원' 까지
# 선택 가능한 이동 수단: WALKING, DRIVING, TRANSIT, BICYCLING
# 이동 수단을 선택하세요: WALKING
# '부천원미공원' 에서 '도당근린공원 백만송이장미원' 까지 이동 수단: WALKING 으로 설정되었습니다.
#
# 경로: '도당근린공원 백만송이장미원' 에서 '삿뽀로 목동점' 까지
# 선택 가능한 이동 수단: WALKING, DRIVING, TRANSIT, BICYCLING
# 이동 수단을 선택하세요: TRANSIT
# '도당근린공원 백만송이장미원' 에서 '삿뽀로 목동점' 까지 이동 수단: TRANSIT 으로 설정되었습니다.
#
# 경로: '삿뽀로 목동점' 에서 '계남제1근린공원' 까지
# 선택 가능한 이동 수단: WALKING, DRIVING, TRANSIT, BICYCLING
# 이동 수단을 선택하세요: TRANSIT
# '삿뽀로 목동점' 에서 '계남제1근린공원' 까지 이동 수단: TRANSIT 으로 설정되었습니다.
#
# 경로: '계남제1근린공원' 에서 '뚜레쥬르 양천캐슬점(신월4동)' 까지
# 선택 가능한 이동 수단: WALKING, DRIVING, TRANSIT, BICYCLING
# 이동 수단을 선택하세요: TRANSIT
# '계남제1근린공원' 에서 '뚜레쥬르 양천캐슬점(신월4동)' 까지 이동 수단: TRANSIT 으로 설정되었습니다.
#
# 경로: '뚜레쥬르 양천캐슬점(신월4동)' 에서 '체육공원' 까지
# 선택 가능한 이동 수단: WALKING, DRIVING, TRANSIT, BICYCLING
# 이동 수단을 선택하세요: WALKING
# '뚜레쥬르 양천캐슬점(신월4동)' 에서 '체육공원' 까지 이동 수단: WALKING 으로 설정되었습니다.
#
# 경로: '체육공원' 에서 '라마다 서울 신도림 호텔' 까지
# 선택 가능한 이동 수단: WALKING, DRIVING, TRANSIT, BICYCLING
# 이동 수단을 선택하세요: WALKING
# '체육공원' 에서 '라마다 서울 신도림 호텔' 까지 이동 수단: WALKING 으로 설정되었습니다.
#
# --- 업데이트된 일정 ---
#   08:00 - 09:00 | 라마다 서울 신도림 호텔 | 다음 이동 수단: WALKING
#   09:00 - 11:00 | 투썸플레이스 가산디지털점 | 다음 이동 수단: WALKING
#   11:00 - 13:00 | 부천원미공원 | 다음 이동 수단: WALKING
#   13:00 - 15:00 | 도당근린공원 백만송이장미원 | 다음 이동 수단: TRANSIT
#   15:00 - 17:00 | 삿뽀로 목동점 | 다음 이동 수단: TRANSIT
#   17:00 - 19:00 | 계남제1근린공원 | 다음 이동 수단: TRANSIT
#   19:00 - 21:00 | 뚜레쥬르 양천캐슬점(신월4동) | 다음 이동 수단: WALKING
#   21:00 - 23:00 | 체육공원 | 다음 이동 수단: WALKING
#   23:00 - 00:00 | 라마다 서울 신도림 호텔 | 다음 이동 수단: 미정
#
# 날짜: 2025-08-03 (알 수 없는 요일)
#
# 경로: '라마다 서울 신도림 호텔' 에서 '뚜레쥬르 대방역점' 까지
# 선택 가능한 이동 수단: WALKING, DRIVING, TRANSIT, BICYCLING
# 이동 수단을 선택하세요: TRANSIT
# '라마다 서울 신도림 호텔' 에서 '뚜레쥬르 대방역점' 까지 이동 수단: TRANSIT 으로 설정되었습니다.
#
# 경로: '뚜레쥬르 대방역점' 에서 '전쟁기념관' 까지
# 선택 가능한 이동 수단: WALKING, DRIVING, TRANSIT, BICYCLING
# 이동 수단을 선택하세요: BICYCLING
# '뚜레쥬르 대방역점' 에서 '전쟁기념관' 까지 이동 수단: BICYCLING 으로 설정되었습니다.
#
# 경로: '전쟁기념관' 에서 '명동대성당' 까지
# 선택 가능한 이동 수단: WALKING, DRIVING, TRANSIT, BICYCLING
# 이동 수단을 선택하세요: DRIVING
# '전쟁기념관' 에서 '명동대성당' 까지 이동 수단: DRIVING 으로 설정되었습니다.
#
# 경로: '명동대성당' 에서 '한일관 타임스퀘어점' 까지
# 선택 가능한 이동 수단: WALKING, DRIVING, TRANSIT, BICYCLING
# 이동 수단을 선택하세요: WALKING
# '명동대성당' 에서 '한일관 타임스퀘어점' 까지 이동 수단: WALKING 으로 설정되었습니다.
#
# 경로: '한일관 타임스퀘어점' 에서 '커피빈 홍대역점' 까지
# 선택 가능한 이동 수단: WALKING, DRIVING, TRANSIT, BICYCLING
# 이동 수단을 선택하세요: DRIVING
# '한일관 타임스퀘어점' 에서 '커피빈 홍대역점' 까지 이동 수단: DRIVING 으로 설정되었습니다.
#
# 경로: '커피빈 홍대역점' 에서 '덕수궁' 까지
# 선택 가능한 이동 수단: WALKING, DRIVING, TRANSIT, BICYCLING
# 이동 수단을 선택하세요: TRANSIT
# '커피빈 홍대역점' 에서 '덕수궁' 까지 이동 수단: TRANSIT 으로 설정되었습니다.
#
# 경로: '덕수궁' 에서 '신도림역' 까지
# 선택 가능한 이동 수단: WALKING, DRIVING, TRANSIT, BICYCLING
# 이동 수단을 선택하세요: WALKING
# '덕수궁' 에서 '신도림역' 까지 이동 수단: WALKING 으로 설정되었습니다.
#
# --- 업데이트된 일정 ---
#   08:00 - 09:00 | 라마다 서울 신도림 호텔 | 다음 이동 수단: TRANSIT
#   09:00 - 11:00 | 뚜레쥬르 대방역점 | 다음 이동 수단: BICYCLING
#   11:00 - 13:00 | 전쟁기념관 | 다음 이동 수단: DRIVING
#   13:00 - 15:00 | 명동대성당 | 다음 이동 수단: WALKING
#   15:00 - 17:00 | 한일관 타임스퀘어점 | 다음 이동 수단: DRIVING
#   17:00 - 19:00 | 커피빈 홍대역점 | 다음 이동 수단: TRANSIT
#   19:00 - 21:00 | 덕수궁 | 다음 이동 수단: WALKING
#   21:00 - 22:00 | 신도림역 | 다음 이동 수단: 미정

# %%
# 4. 전체 여행 경로 시각화 (하나의 지도) - 사용자 선택 이동 수단 반영

# tables_with_modes 변수가 바로 위 셀 (이동 수단 선택) 실행 후 생성되었다고 가정합니다.
# visualize_full_route 함수 (위에 정의된 함수 사용)

if 'tables_with_modes' in locals() and tables_with_modes:
    print("\n--- 전체 여행 경로 시각화 (사용자 선택 이동 수단 반영) ---")
    full_route_map = visualize_full_route(tables_with_modes)
    if full_route_map:
        display(full_route_map)
    else:
        print("전체 경로 시각화에 실패했습니다.")
else:
     print("이동 수단이 선택된 여행 기록 데이터가 준비되지 않았습니다. 이전 셀들을 실행해주세요.")
# Out:
# --- 전체 여행 경로 시각화 (사용자 선택 이동 수단 반영) ---
# 경로 API 실패 (WALKING): 신도림역에서 참새어린이공원까지 직선으로 연결합니다.
# 경로 API 실패 (DRIVING): 참새어린이공원에서 파스쿠찌 보라매공원점까지 직선으로 연결합니다.
# 경로 API 실패 (DRIVING): 파스쿠찌 보라매공원점에서 막내회센타까지 직선으로 연결합니다.
# 경로 API 실패 (TRANSIT): 막내회센타에서 국립중앙박물관까지 직선으로 연결합니다.
# 경로 API 실패 (BICYCLING): 국립중앙박물관에서 N서울타워까지 직선으로 연결합니다.
# 경로 API 실패 (DRIVING): N서울타워에서 광화문광장까지 직선으로 연결합니다.
# 경로 API 실패 (WALKING): 광화문광장에서 라마다 서울 신도림 호텔까지 직선으로 연결합니다.
# 경로 API 실패 (WALKING): 라마다 서울 신도림 호텔에서 투썸플레이스 가산디지털점까지 직선으로 연결합니다.
# 경로 API 실패 (WALKING): 투썸플레이스 가산디지털점에서 부천원미공원까지 직선으로 연결합니다.
# 경로 API 실패 (WALKING): 부천원미공원에서 도당근린공원 백만송이장미원까지 직선으로 연결합니다.
# 경로 API 실패 (TRANSIT): 도당근린공원 백만송이장미원에서 삿뽀로 목동점까지 직선으로 연결합니다.
# 경로 API 실패 (TRANSIT): 삿뽀로 목동점에서 계남제1근린공원까지 직선으로 연결합니다.
# 경로 API 실패 (TRANSIT): 계남제1근린공원에서 뚜레쥬르 양천캐슬점(신월4동)까지 직선으로 연결합니다.
# 경로 API 실패 (WALKING): 뚜레쥬르 양천캐슬점(신월4동)에서 체육공원까지 직선으로 연결합니다.
# 경로 API 실패 (WALKING): 체육공원에서 라마다 서울 신도림 호텔까지 직선으로 연결합니다.
# 경로 API 실패 (TRANSIT): 라마다 서울 신도림 호텔에서 뚜레쥬르 대방역점까지 직선으로 연결합니다.
# 경로 API 실패 (BICYCLING): 뚜레쥬르 대방역점에서 전쟁기념관까지 직선으로 연결합니다.
# 경로 API 실패 (DRIVING): 전쟁기념관에서 명동대성당까지 직선으로 연결합니다.
# 경로 API 실패 (WALKING): 명동대성당에서 한일관 타임스퀘어점까지 직선으로 연결합니다.
# 경로 API 실패 (DRIVING): 한일관 타임스퀘어점에서 커피빈 홍대역점까지 직선으로 연결합니다.
# 경로 API 실패 (TRANSIT): 커피빈 홍대역점에서 덕수궁까지 직선으로 연결합니다.
# 경로 API 실패 (WALKING): 덕수궁에서 신도림역까지 직선으로 연결합니다.
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_29a9ed8f25dec866022ff5049b921ddc {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_29a9ed8f25dec866022ff5049b921ddc&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_29a9ed8f25dec866022ff5049b921ddc = L.map(
#                 &quot;map_29a9ed8f25dec866022ff5049b921ddc&quot;,
#                 {
#                     center: [37.5088099, 126.8912061],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1ad5cbcb3be1838a5dd029129d3aa00d = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_1ad5cbcb3be1838a5dd029129d3aa00d.addTo(map_29a9ed8f25dec866022ff5049b921ddc);
#
#
#             var marker_54dcedd6fa1841afeaa63afcddc6bddb = L.marker(
#                 [37.5088099, 126.8912061],
#                 {
# }
#             ).addTo(map_29a9ed8f25dec866022ff5049b921ddc);
#
#
#             var icon_177fef01d8e300be7cb02b537a13e56d = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_8a45af1f1cd6d8104203a3034bc2a930 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ba2dace780d6e89d6700fd75324944d3 = $(`&lt;div id=&quot;html_ba2dace780d6e89d6700fd75324944d3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;1일차&lt;/b&gt; - &lt;b&gt;1번째 방문&lt;/b&gt;&lt;br&gt;신도림역&lt;br&gt;(09:00~10:00)&lt;br&gt;다음 이동: WALKING&lt;/div&gt;`)[0];
#                 popup_8a45af1f1cd6d8104203a3034bc2a930.setContent(html_ba2dace780d6e89d6700fd75324944d3);
#
#
#
#         marker_54dcedd6fa1841afeaa63afcddc6bddb.bindPopup(popup_8a45af1f1cd6d8104203a3034bc2a930)
#         ;
#
#
#
#
#                 marker_54dcedd6fa1841afeaa63afcddc6bddb.setIcon(icon_177fef01d8e300be7cb02b537a13e56d);
#
#
#             var marker_44a93385bcc5bbada2afa93c2784ec29 = L.marker(
#                 [37.49805560000001, 126.9219444],
#                 {
# }
#             ).addTo(map_29a9ed8f25dec866022ff5049b921ddc);
#
#
#             var icon_4b0df0a14d0abd96412fb77a20c61eb1 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_adff6dbf305e8e903074725e9316036d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_13e789433f0bad9afd84f5d036c92162 = $(`&lt;div id=&quot;html_13e789433f0bad9afd84f5d036c92162&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;1일차&lt;/b&gt; - &lt;b&gt;2번째 방문&lt;/b&gt;&lt;br&gt;참새어린이공원&lt;br&gt;(10:00~12:00)&lt;br&gt;다음 이동: DRIVING&lt;/div&gt;`)[0];
#                 popup_adff6dbf305e8e903074725e9316036d.setContent(html_13e789433f0bad9afd84f5d036c92162);
#
#
#
#         marker_44a93385bcc5bbada2afa93c2784ec29.bindPopup(popup_adff6dbf305e8e903074725e9316036d)
#         ;
#
#
#
#
#                 marker_44a93385bcc5bbada2afa93c2784ec29.setIcon(icon_4b0df0a14d0abd96412fb77a20c61eb1);
#
#
#             var marker_8bd8124c407ca0afd12181347ed7e25c = L.marker(
#                 [37.4972922, 126.9165608],
#                 {
# }
#             ).addTo(map_29a9ed8f25dec866022ff5049b921ddc);
#
#
#             var icon_77022f49c8828b26120fefee14efdc9f = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_978e53380df15a023746183843fadc84 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_177cd1f40a1f1041e4c34290901e6078 = $(`&lt;div id=&quot;html_177cd1f40a1f1041e4c34290901e6078&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;1일차&lt;/b&gt; - &lt;b&gt;3번째 방문&lt;/b&gt;&lt;br&gt;파스쿠찌 보라매공원점&lt;br&gt;(12:00~14:00)&lt;br&gt;다음 이동: DRIVING&lt;/div&gt;`)[0];
#                 popup_978e53380df15a023746183843fadc84.setContent(html_177cd1f40a1f1041e4c34290901e6078

# %%
# 5. 날짜별 여행 경로 시각화 (각 날짜별 별도의 지도) - 사용자 선택 이동 수단 반영

# tables_with_modes 변수가 이동 수단 선택 셀 실행 후 생성되었다고 가정합니다.
# visualize_daily_routes 함수 (위에 정의된 함수 사용)

if 'tables_with_modes' in locals() and tables_with_modes:
    print("\n--- 날짜별 여행 경로 시각화 (사용자 선택 이동 수단 반영) ---")
    visualize_daily_routes(tables_with_modes)
else:
     print("이동 수단이 선택된 여행 기록 데이터가 준비되지 않았습니다. 이전 셀들을 실행해주세요.")
# Out:
# --- 날짜별 여행 경로 시각화 (사용자 선택 이동 수단 반영) ---
#
# --- 2025-08-01 (알 수 없는 요일) 여행 경로 ---
# 경로 API 실패 (WALKING): 신도림역에서 참새어린이공원까지 직선으로 연결합니다.
# 경로 API 실패 (DRIVING): 참새어린이공원에서 파스쿠찌 보라매공원점까지 직선으로 연결합니다.
# 경로 API 실패 (DRIVING): 파스쿠찌 보라매공원점에서 막내회센타까지 직선으로 연결합니다.
# 경로 API 실패 (TRANSIT): 막내회센타에서 국립중앙박물관까지 직선으로 연결합니다.
# 경로 API 실패 (BICYCLING): 국립중앙박물관에서 N서울타워까지 직선으로 연결합니다.
# 경로 API 실패 (DRIVING): N서울타워에서 광화문광장까지 직선으로 연결합니다.
# 경로 API 실패 (WALKING): 광화문광장에서 라마다 서울 신도림 호텔까지 직선으로 연결합니다.
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5fa95068255b21c0207293187f20cd21 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5fa95068255b21c0207293187f20cd21&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5fa95068255b21c0207293187f20cd21 = L.map(
#                 &quot;map_5fa95068255b21c0207293187f20cd21&quot;,
#                 {
#                     center: [37.5088099, 126.8912061],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_31b51c4e15b27dc36666b879f5b1c600 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_31b51c4e15b27dc36666b879f5b1c600.addTo(map_5fa95068255b21c0207293187f20cd21);
#
#
#             var marker_ddc5e93e5be3f994ee60ef9b566d6e0e = L.marker(
#                 [37.5088099, 126.8912061],
#                 {
# }
#             ).addTo(map_5fa95068255b21c0207293187f20cd21);
#
#
#             var icon_bfed34fb515ee41e726ffdf1f15cc50d = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;play&quot;,
#   &quot;prefix&quot;: &quot;fa&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_1db8491b3fe5afed6d0ef52b2ca2f1e5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_570d7d382fb2f05e6ea3d01e73382be5 = $(`&lt;div id=&quot;html_570d7d382fb2f05e6ea3d01e73382be5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;방문 순서 #1&lt;/b&gt;&lt;br&gt;신도림역&lt;br&gt;(09:00~10:00)&lt;br&gt;다음 이동: WALKING&lt;/div&gt;`)[0];
#                 popup_1db8491b3fe5afed6d0ef52b2ca2f1e5.setContent(html_570d7d382fb2f05e6ea3d01e73382be5);
#
#
#
#         marker_ddc5e93e5be3f994ee60ef9b566d6e0e.bindPopup(popup_1db8491b3fe5afed6d0ef52b2ca2f1e5)
#         ;
#
#
#
#
#                 marker_ddc5e93e5be3f994ee60ef9b566d6e0e.setIcon(icon_bfed34fb515ee41e726ffdf1f15cc50d);
#
#
#             var marker_a680c02fee2b7881b12cfabf57440984 = L.marker(
#                 [37.49805560000001, 126.9219444],
#                 {
# }
#             ).addTo(map_5fa95068255b21c0207293187f20cd21);
#
#
#             var icon_22eaae5e22f51614d4dae824b4720118 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info&quot;,
#   &quot;prefix&quot;: &quot;fa&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_fb59c15805d40d738ad7401435152e29 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5870e9a6bf534ef7823fcb605e84ad63 = $(`&lt;div id=&quot;html_5870e9a6bf534ef7823fcb605e84ad63&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;방문 순서 #2&lt;/b&gt;&lt;br&gt;참새어린이공원&lt;br&gt;(10:00~12:00)&lt;br&gt;다음 이동: DRIVING&lt;/div&gt;`)[0];
#                 popup_fb59c15805d40d738ad7401435152e29.setContent(html_5870e9a6bf534ef7823fcb605e84ad63);
#
#
#
#         marker_a680c02fee2b7881b12cfabf57440984.bindPopup(popup_fb59c15805d40d738ad7401435152e29)
#         ;
#
#
#
#
#                 marker_a680c02fee2b7881b12cfabf57440984.setIcon(icon_22eaae5e22f51614d4dae824b4720118);
#
#
#             var marker_77950f7744095428a4d64b6339f52576 = L.marker(
#                 [37.4972922, 126.9165608],
#                 {
# }
#             ).addTo(map_5fa95068255b21c0207293187f20cd21);
#
#
#             var icon_6c0c0f211b2b81d26619b60fb96ac24c = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info&quot;,
#   &quot;prefix&quot;: &quot;fa&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_d4ce2e24a5db8098d20e094e044daa01 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b627dd92648f993d3bcc5f8242dcf2bd = $(`&lt;div id=&quot;html_b627dd92648f993d3bcc5f8242dcf2bd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;방문 순서 #3&lt;/b&gt;&lt;br&gt;파스쿠찌 보라매공원점&lt;br&gt;(12:00~14:00)&lt;br&gt;다음 이동: DRIVING&lt;/div&gt;`)[0];
#                 popup_d4ce2e24a5db8098d20e094e044daa01.setContent(html_b627dd92648f993d3bcc5f8242dcf2bd);
#
#
#
#         marker_77950f7744095428a4d64b6339f52576.bindPopup(popup_d4ce2e24a5db8
# --- 2025-08-02 (알 수 없는 요일) 여행 경로 ---
# 경로 API 실패 (WALKING): 라마다 서울 신도림 호텔에서 투썸플레이스 가산디지털점까지 직선으로 연결합니다.
# 경로 API 실패 (WALKING): 투썸플레이스 가산디지털점에서 부천원미공원까지 직선으로 연결합니다.
# 경로 API 실패 (WALKING): 부천원미공원에서 도당근린공원 백만송이장미원까지 직선으로 연결합니다.
# 경로 API 실패 (TRANSIT): 도당근린공원 백만송이장미원에서 삿뽀로 목동점까지 직선으로 연결합니다.
# 경로 API 실패 (TRANSIT): 삿뽀로 목동점에서 계남제1근린공원까지 직선으로 연결합니다.
# 경로 API 실패 (TRANSIT): 계남제1근린공원에서 뚜레쥬르 양천캐슬점(신월4동)까지 직선으로 연결합니다.
# 경로 API 실패 (WALKING): 뚜레쥬르 양천캐슬점(신월4동)에서 체육공원까지 직선으로 연결합니다.
# 경로 API 실패 (WALKING): 체육공원에서 라마다 서울 신도림 호텔까지 직선으로 연결합니다.
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_54c5fdcb5ff23a973835d2c4eae26e33 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_54c5fdcb5ff23a973835d2c4eae26e33&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_54c5fdcb5ff23a973835d2c4eae26e33 = L.map(
#                 &quot;map_54c5fdcb5ff23a973835d2c4eae26e33&quot;,
#                 {
#                     center: [37.5064312, 126.885321],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9a54f6384d10f38821187370647bc779 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_9a54f6384d10f38821187370647bc779.addTo(map_54c5fdcb5ff23a973835d2c4eae26e33);
#
#
#             var marker_50cda56ea34541654607baf85d7e0407 = L.marker(
#                 [37.5064312, 126.885321],
#                 {
# }
#             ).addTo(map_54c5fdcb5ff23a973835d2c4eae26e33);
#
#
#             var icon_769cfafe354e227448d13146dadd697d = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;play&quot;,
#   &quot;prefix&quot;: &quot;fa&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_0b2e62fe21098c96ef7ada3dcaa86745 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_55b6d9793d1333949123d3417a431c95 = $(`&lt;div id=&quot;html_55b6d9793d1333949123d3417a431c95&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;방문 순서 #1&lt;/b&gt;&lt;br&gt;라마다 서울 신도림 호텔&lt;br&gt;(08:00~09:00)&lt;br&gt;다음 이동: WALKING&lt;/div&gt;`)[0];
#                 popup_0b2e62fe21098c96ef7ada3dcaa86745.setContent(html_55b6d9793d1333949123d3417a431c95);
#
#
#
#         marker_50cda56ea34541654607baf85d7e0407.bindPopup(popup_0b2e62fe21098c96ef7ada3dcaa86745)
#         ;
#
#
#
#
#                 marker_50cda56ea34541654607baf85d7e0407.setIcon(icon_769cfafe354e227448d13146dadd697d);
#
#
#             var marker_c9d15cbd52fd92177d40c98f52b6ed85 = L.marker(
#                 [37.48193200000001, 126.881509],
#                 {
# }
#             ).addTo(map_54c5fdcb5ff23a973835d2c4eae26e33);
#
#
#             var icon_326b40dd2187ca25a2d44dbae55829a8 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info&quot;,
#   &quot;prefix&quot;: &quot;fa&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_b4ca4ab52676f83bddbb92588639c0bb = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d29d467b2c9d7feb2c349474e5f6b8c6 = $(`&lt;div id=&quot;html_d29d467b2c9d7feb2c349474e5f6b8c6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;방문 순서 #2&lt;/b&gt;&lt;br&gt;투썸플레이스 가산디지털점&lt;br&gt;(09:00~11:00)&lt;br&gt;다음 이동: WALKING&lt;/div&gt;`)[0];
#                 popup_b4ca4ab52676f83bddbb92588639c0bb.setContent(html_d29d467b2c9d7feb2c349474e5f6b8c6);
#
#
#
#         marker_c9d15cbd52fd92177d40c98f52b6ed85.bindPopup(popup_b4ca4ab52676f83bddbb92588639c0bb)
#         ;
#
#
#
#
#                 marker_c9d15cbd52fd92177d40c98f52b6ed85.setIcon(icon_326b40dd2187ca25a2d44dbae55829a8);
#
#
#             var marker_03e4220ed963932b1e990387829c5963 = L.marker(
#                 [37.498023, 126.798905],
#                 {
# }
#             ).addTo(map_54c5fdcb5ff23a973835d2c4eae26e33);
#
#
#             var icon_c566e8e778fb1fd94d4276fcfc49c1c4 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info&quot;,
#   &quot;prefix&quot;: &quot;fa&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_d8ba60d6aefd041257c7eb96446b27d8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ddc24c94266a3a262ceabb5f2782d847 = $(`&lt;div id=&quot;html_ddc24c94266a3a262ceabb5f2782d847&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;방문 순서 #3&lt;/b&gt;&lt;br&gt;부천원미공원&lt;br&gt;(11:00~13:00)&lt;br&gt;다음 이동: WALKING&lt;/div&gt;`)[0];
#                 popup_d8ba60d6aefd041257c7eb96446b27d8.setContent(html_ddc24c94266a3a262ceabb5f2782d847);
#
#
#
#         marker_03e4220ed963932b1e990387829c5963.bindPopup(popup_d8ba60
# --- 2025-08-03 (알 수 없는 요일) 여행 경로 ---
# 경로 API 실패 (TRANSIT): 라마다 서울 신도림 호텔에서 뚜레쥬르 대방역점까지 직선으로 연결합니다.
# 경로 API 실패 (BICYCLING): 뚜레쥬르 대방역점에서 전쟁기념관까지 직선으로 연결합니다.
# 경로 API 실패 (DRIVING): 전쟁기념관에서 명동대성당까지 직선으로 연결합니다.
# 경로 API 실패 (WALKING): 명동대성당에서 한일관 타임스퀘어점까지 직선으로 연결합니다.
# 경로 API 실패 (DRIVING): 한일관 타임스퀘어점에서 커피빈 홍대역점까지 직선으로 연결합니다.
# 경로 API 실패 (TRANSIT): 커피빈 홍대역점에서 덕수궁까지 직선으로 연결합니다.
# 경로 API 실패 (WALKING): 덕수궁에서 신도림역까지 직선으로 연결합니다.
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2bb3f27004edaffc0d83896a1d2341e1 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2bb3f27004edaffc0d83896a1d2341e1&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_2bb3f27004edaffc0d83896a1d2341e1 = L.map(
#                 &quot;map_2bb3f27004edaffc0d83896a1d2341e1&quot;,
#                 {
#                     center: [37.5064312, 126.885321],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_539cabecab78421295e7bef63cfcd7c0 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_539cabecab78421295e7bef63cfcd7c0.addTo(map_2bb3f27004edaffc0d83896a1d2341e1);
#
#
#             var marker_c2d42fd31e61ae7ee7970b06c10e8664 = L.marker(
#                 [37.5064312, 126.885321],
#                 {
# }
#             ).addTo(map_2bb3f27004edaffc0d83896a1d2341e1);
#
#
#             var icon_ff81f01595e49a289c1d92488da8ece7 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;play&quot;,
#   &quot;prefix&quot;: &quot;fa&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_5bb1b5b1c48d91b3fa36dbba40c0ddd2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_dc956246b4e0e8824af5f04f1176e193 = $(`&lt;div id=&quot;html_dc956246b4e0e8824af5f04f1176e193&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;방문 순서 #1&lt;/b&gt;&lt;br&gt;라마다 서울 신도림 호텔&lt;br&gt;(08:00~09:00)&lt;br&gt;다음 이동: TRANSIT&lt;/div&gt;`)[0];
#                 popup_5bb1b5b1c48d91b3fa36dbba40c0ddd2.setContent(html_dc956246b4e0e8824af5f04f1176e193);
#
#
#
#         marker_c2d42fd31e61ae7ee7970b06c10e8664.bindPopup(popup_5bb1b5b1c48d91b3fa36dbba40c0ddd2)
#         ;
#
#
#
#
#                 marker_c2d42fd31e61ae7ee7970b06c10e8664.setIcon(icon_ff81f01595e49a289c1d92488da8ece7);
#
#
#             var marker_f4b71b7f8f0f66abbe44da92ddc0128d = L.marker(
#                 [37.5099498, 126.9246002],
#                 {
# }
#             ).addTo(map_2bb3f27004edaffc0d83896a1d2341e1);
#
#
#             var icon_a23605e496017ed31a4634972334bf2d = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info&quot;,
#   &quot;prefix&quot;: &quot;fa&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_3b94b41f3e9a71dbace9789ad2bcaffe = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_bdbc3f2749d9cf4adc8a7cbfd8aa696e = $(`&lt;div id=&quot;html_bdbc3f2749d9cf4adc8a7cbfd8aa696e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;방문 순서 #2&lt;/b&gt;&lt;br&gt;뚜레쥬르 대방역점&lt;br&gt;(09:00~11:00)&lt;br&gt;다음 이동: BICYCLING&lt;/div&gt;`)[0];
#                 popup_3b94b41f3e9a71dbace9789ad2bcaffe.setContent(html_bdbc3f2749d9cf4adc8a7cbfd8aa696e);
#
#
#
#         marker_f4b71b7f8f0f66abbe44da92ddc0128d.bindPopup(popup_3b94b41f3e9a71dbace9789ad2bcaffe)
#         ;
#
#
#
#
#                 marker_f4b71b7f8f0f66abbe44da92ddc0128d.setIcon(icon_a23605e496017ed31a4634972334bf2d);
#
#
#             var marker_ebbbdbcaf10648015f7917974f312b27 = L.marker(
#                 [37.5366059, 126.9771397],
#                 {
# }
#             ).addTo(map_2bb3f27004edaffc0d83896a1d2341e1);
#
#
#             var icon_35968139bbf9be009f56c6c7b467f0d5 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info&quot;,
#   &quot;prefix&quot;: &quot;fa&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_0c9c0a24b56933e08e42b9a6c9658737 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5a2ed44643acd51586bdea6ef15fd30c = $(`&lt;div id=&quot;html_5a2ed44643acd51586bdea6ef15fd30c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;방문 순서 #3&lt;/b&gt;&lt;br&gt;전쟁기념관&lt;br&gt;(11:00~13:00)&lt;br&gt;다음 이동: DRIVING&lt;/div&gt;`)[0];
#                 popup_0c9c0a24b56933e08e42b9a6c9658737.setContent(html_5a2ed44643acd51586bdea6ef15fd30c);
#
#
#
#         marker_ebbbdbcaf10648015f7917974f312b27.bindPopup(popup_0c9c0a24b56
