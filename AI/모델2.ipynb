# %%
import json

with open("all_places.json", "r", encoding="utf-8") as f:
    all_places = json.load(f)

# %%
# %pip install transformers
# Out:
# Requirement already satisfied: transformers in c:\users\hyi1102\anaconda3\lib\site-packages (4.53.1)
# Requirement already satisfied: filelock in c:\users\hyi1102\anaconda3\lib\site-packages (from transformers) (3.13.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.30.0 in c:\users\hyi1102\anaconda3\lib\site-packages (from transformers) (0.33.2)
# Requirement already satisfied: numpy>=1.17 in c:\users\hyi1102\anaconda3\lib\site-packages (from transformers) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\hyi1102\anaconda3\lib\site-packages (from transformers) (23.1)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\hyi1102\anaconda3\lib\site-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\hyi1102\anaconda3\lib\site-packages (from transformers) (2023.10.3)
# Requirement already satisfied: requests in c:\users\hyi1102\anaconda3\lib\site-packages (from transformers) (2.30.0)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in c:\users\hyi1102\anaconda3\lib\site-packages (from transformers) (0.21.2)
# Requirement already satisfied: safetensors>=0.4.3 in c:\users\hyi1102\anaconda3\lib\site-packages (from transformers) (0.5.3)
# Requirement already satisfied: tqdm>=4.27 in c:\users\hyi1102\anaconda3\lib\site-packages (from transformers) (4.65.0)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\hyi1102\anaconda3\lib\site-packages (from huggingface-hub<1.0,>=0.30.0->transformers) (2023.10.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\hyi1102\anaconda3\lib\site-packages (from huggingface-hub<1.0,>=0.30.0->transformers) (4.12.2)
# Requirement already satisfied: colorama in c:\users\hyi1102\anaconda3\lib\site-packages (from tqdm>=4.27->transformers) (0.4.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\hyi1102\anaconda3\lib\site-packages (from requests->transformers) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\hyi1102\anaconda3\lib\site-packages (from requests->transformers) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\hyi1102\anaconda3\lib\site-packages (from requests->transformers) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\hyi1102\anaconda3\lib\site-packages (from requests->transformers) (2025.1.31)
# Note: you may need to restart the kernel to use updated packages.

# %%
import re
import html

def clean_review(text):
    if not isinstance(text, str):
        return None

    text = html.unescape(text)
    text = text.strip()

    if len(text) < 3:
        return None

    if not re.search("[가-힣]", text):  # 한글 없는 외국어 리뷰 제거
        return None

    text = re.sub(r"(.)\1{2,}", r"\1\1", text)  # 반복 문자 정리
    text = re.sub(r"[^\w\s가-힣.,!?]", "", text)  # 이모지, 특수문자 제거
    text = text[:300]  # 너무 긴 리뷰 자르기

    return text if text else None

for place in all_places:
    original_reviews = place.get("reviews", [])
    cleaned_reviews = []

    for review in original_reviews:
        cleaned = clean_review(review)
        if cleaned:
            cleaned_reviews.append(cleaned)

    place["reviews"] = cleaned_reviews  # ✅ 전처리된 리뷰로 덮어쓰기

# %%
#user_input_raw = input("여행에서 어떤 걸 원하시나요?\n")
user_input_raw = "공원이 싫어 타워 위주의 여행을 원해. 예 스카이타워"

# 리뷰 전처리 함수 사용
user_cleaned = clean_review(user_input_raw)

from transformers import AutoTokenizer, AutoModelForSequenceClassification
import torch

# 모델 로드 (이진 분류 기반으로 사전학습된 모델 사용)
tokenizer = AutoTokenizer.from_pretrained("klue/roberta-base")
model = AutoModelForSequenceClassification.from_pretrained("klue/roberta-base")
model.eval()

import re

def is_korean(text):
    return bool(re.search("[가-힣]", text))

def is_valid_review(text):
    if not isinstance(text, str) or len(text.strip()) < 5:
        return False
    else:
        return True

def trimmed_mean(scores, trim_ratio=0.25):
    if len(scores) < 3:
        return sum(scores) / len(scores)
    scores = sorted(scores)
    n = int(len(scores) * trim_ratio)
    trimmed = scores[n:-n] if n > 0 else scores
    return sum(trimmed) / len(trimmed)

# Transformer 기반 적합도 추론 함수
def transformer_score(user_text, place_name, place_reviews, max_review_count=5):
    valid_reviews = [
        r for r in place_reviews
        if is_valid_review(r) and is_korean(r)
    ]
    if not valid_reviews:
        return 0.0

    scores = []
    for review in valid_reviews[:max_review_count]:
        combined_text = f"{place_name}. {review}"  # ⬅️ 명소 이름 포함
        inputs = tokenizer(user_text, combined_text, return_tensors="pt", truncation=True, max_length=512)
        with torch.no_grad():
            logits = model(**inputs).logits
            score = torch.sigmoid(logits[0][0]).item()
            scores.append(score)

    return round(sum(scores) / len(scores), 4) if scores else 0.0

for place in all_places:
    reviews = place.get("reviews", [])
    place["transformer_score"] = transformer_score(user_cleaned, place["name"], place.get("reviews", []))
# Out:
# Some weights of RobertaForSequenceClassification were not initialized from the model checkpoint at klue/roberta-base and are newly initialized: ['classifier.dense.bias', 'classifier.dense.weight', 'classifier.out_proj.bias', 'classifier.out_proj.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
from collections import defaultdict

# 분야별 분류
type_to_places = defaultdict(list)

for place in all_places:
    place_type = place.get("type", "unknown")
    type_to_places[place_type].append(place)

# 분야별 Top 5 출력
print("\n📊 분야별 Transformer 적합도 Top 5:")

for place_type, places in type_to_places.items():
    print(f"\n🔹 {place_type.title()}:")

    sorted_by_score = sorted(places, key=lambda x: x["transformer_score"], reverse=True)
    for i, place in enumerate(sorted_by_score[:], 1):
        print(f"  {i}. {place['name']} ({place['vicinity']})")
        print(f"     적합도: {place['transformer_score']:.4f}, 평점: {place['rating']}, 리뷰 수: {place['user_ratings_total']}")
# Out:
# 📊 분야별 Transformer 적합도 Top 5:
#
# 🔹 Tourist_Attraction:
#   1. 원효대교 (영등포구 여의동)
#      적합도: 0.5754, 평점: 4.2, 리뷰 수: 104
#   2. 남대문시장 (중구 남대문시장4길 21)
#      적합도: 0.5752, 평점: 4.2, 리뷰 수: 27492
#   3. 돈의문(서대문) 터 (종로구 신문로2가)
#      적합도: 0.5744, 평점: 3.9, 리뷰 수: 51
#   4. 덕수궁 (중구 세종대로 99)
#      적합도: 0.5742, 평점: 4.6, 리뷰 수: 19738
#   5. 목마공원 (양천구 목동 910)
#      적합도: 0.5742, 평점: 3.8, 리뷰 수: 108
#   6. 서울월드컵경기장 (마포구 월드컵로 240)
#      적합도: 0.5738, 평점: 4.4, 리뷰 수: 9215
#   7. 가로공원 (양천구 신월동)
#      적합도: 0.5735, 평점: 3.5, 리뷰 수: 49
#   8. 금천교 (금천구 독산동)
#      적합도: 0.5733, 평점: 3.9, 리뷰 수: 169
#   9. 궁뜰어린이공원 (서대문구 연희동 123-5)
#      적합도: 0.5733, 평점: 4.3, 리뷰 수: 93
#   10. 부천레포츠공원 (부천시 원미구 춘의동)
#      적합도: 0.5733, 평점: 4.2, 리뷰 수: 48
#   11. 매화근린공원 (강서구 등촌동)
#      적합도: 0.5732, 평점: 4.1, 리뷰 수: 29
#   12. 전쟁기념관 (용산구 이태원로 29)
#      적합도: 0.5727, 평점: 4.6, 리뷰 수: 17543
#   13. 거리공원 (구로구 공원로 73-1)
#      적합도: 0.5727, 평점: 4.2, 리뷰 수: 842
#   14. 도당근린공원 백만송이장미원 (부천시 원미구 부천로354번길 100)
#      적합도: 0.5726, 평점: 4.2, 리뷰 수: 1501
#   15. 방아다리공원 (양천구 신월동)
#      적합도: 0.5725, 평점: 4.2, 리뷰 수: 27
#   16. 방화쌈지공원 (강서구 방화동)
#      적합도: 0.5723, 평점: 4.1, 리뷰 수: 167
#   17. 63빌딩 (영등포구 63로 50)
#      적합도: 0.5722, 평점: 4.2, 리뷰 수: 9539
#   18. 국립중앙박물관 (용산구 서빙고로 137)
#      적합도: 0.5721, 평점: 4.7, 리뷰 수: 26342
#   19. 증산체육공원 (은평구 증산동 산18-6)
#      적합도: 0.5720, 평점: 3.9, 리뷰 수: 208
#   20. 서래섬 (서초구 신반포로11길 40)
#      적합도: 0.5719, 평점: 4.4, 리뷰 수: 762
#   21. 한마음어린이공원 (마포구 망원동)
#      적합도: 0.5719, 평점: 4, 리뷰 수: 35
#   22. 까치산근린공원 (동작구 사당제1동)
#      적합도: 0.5718, 평점: 4.3, 리뷰 수: 203
#   23. 구로리 어린이공원 (구로구 구로동)
#      적합도: 0.5718, 평점: 3.6, 리뷰 수: 512
#   24. N서울타워 (용산구 남산공원길 105)
#      적합도: 0.5717, 평점: 4.5, 리뷰 수: 63535
#   25. 산기슭공원 (금천구 시흥동)
#      적합도: 0.5717, 평점: 4.2, 리뷰 수: 228
#   26. 부천원미공원 (부천시 소사로 456)
#      적합도: 0.5716, 평점: 4.3, 리뷰 수: 289
#   27. 덕수공원 (관악구 봉천동)
#      적합도: 0.5714, 평점: 3.7, 리뷰 수: 51
#   28. 잣절공원 (구로구 개봉동)
#      적합도: 0.5713, 평점: 4.3, 리뷰 수: 330
#   29. 계남제1근린공원 (양천구 신정동)
#      적합도: 0.5713, 평점: 4.3, 리뷰 수: 178
#   30. 관악산 자연공원 (관악구 신림동 산32-24)
#      적합도: 0.5713, 평점: 4.6, 리뷰 수: 72
#   31. 흑석동공원 (동작구 흑석동)
#      적합도: 0.5712, 평점: 4.4, 리뷰 수: 97
#   32. 참새어린이공원 (동작구 대방동)
#      적합도: 0.5708, 평점: 4.2, 리뷰 수: 249
#   33. 은가어린이공원 (서대문구 북가좌동)
#      적합도: 0.5707, 평점: 3.8, 리뷰 수: 266
#   34. 너부대근린공원 (광명시 광명동)
#      적합도: 0.5706, 평점: 4.2, 리뷰 수: 59
#   35. 경희궁 (종로구 새문안로 45)
#      적합도: 0.5705, 평점: 4.4, 리뷰 수: 1173
#   36. 이화여자대학교 자연사박물관 (서대문구 이화여대길 52)
#      적합도: 0.5705, 평점: 4.4, 리뷰 수: 111
#   37. 무궁화어린이공원 (관악구 신림동)
#      적합도: 0.5703, 평점: 3.9, 리뷰 수: 116
#   38. 철망산공원 (광명시 하안동 683)
#      적합도: 0.5698, 평점: 4.1, 리뷰 수: 74
#   39. 마을숲공원 (동작구 상도동)
#      적합도: 0.5697, 평점: 4.2, 리뷰 수: 18
#   40. 백로어린이공원 (동작구 상도동)
#      적합도: 0.5693, 평점: 4, 리뷰 수: 106
#
# 🔹 Cafe:
#   1. 투썸플레이스 가산디지털점 (금천구 가산동 459-11 JEI플라츠 1층)
#      적합도: 0.5728, 평점: 3.9, 리뷰 수: 192
#   2. 고양이다락방 홍대점 (마포구 홍익로6길 21)
#      적합도: 0.5727, 평점: 4.3, 리뷰 수: 303
#   3. 신촌미플 (서대문구 신촌로 109)
#      적합도: 0.5722, 평점: 4.1, 리뷰 수: 91
#   4. 투썸플레이스 서여의도점 (영등포구 국회대로70길 15-1 1층)
#      적합도: 0.5721, 평점: 3.8, 리뷰 수: 120
#   5. 아프리카 (서초구 방배본동 756-7)
#      적합도: 0.5720, 평점: 4, 리뷰 수: 2
#   6. 투썸플레이스 서강대점 (마포구 신수동 서강대학교 금호아시아나바오로경영관 1층)
#      적합도: 0.5719, 평점: 4, 리뷰 수: 45
#   7. 재미난조각가 (South Korea)
#      적합도: 0.5717, 평점: 3.6, 리뷰 수: 76
#   8. 투썸플레이스 서울대역중앙점 (관악구 중앙동 861-7)
#      적합도: 0.5716, 평점: 3.9, 리뷰 수: 125
#   9. 아리스타커피 등촌점 (강서구 강서로56가길 53 1층)
#      적합도: 0.5715, 평점: 3.7, 리뷰 수: 14
#   10. 투썸플레이스 신림역점 (관악구 신림로 350)
#      적합도: 0.5713, 평점: 3.7, 리뷰 수: 199
#   11. 파스쿠찌보라매공원점 (영등포구 신길동 4327)
#      적합도: 0.5711, 평점: 4, 리뷰 수: 203
#   12. 엔제리너스 선유도역점 (영등포구 양평로21길 10 1 층)
#      적합도: 0.5710, 평점: 3.6, 리뷰 수: 11
#   13. 동작노을카페 (동작구 동작대로 335)
#      적합도: 0.5709, 평점: 4.4, 리뷰 수: 1204
#   14. 이디야커피 서여의도점 (영등포구 국회대로72길 4)
#      적합도: 0.5706, 평점: 4, 리뷰 수: 116
#   15. 이디야커피 구일역점 (구로구 구로동 642-108)
#      적합도: 0.5705, 평점: 3.9, 리뷰 수: 81
#   16. bar sting (구로구 개봉제3동)
#      적합도: 0.5705, 평점: 4.3, 리뷰 수: 3
#   17. Bread Fit (영등포구 지하1층 133)
#      적합도: 0.5703, 평점: 4.3, 리뷰 수: 79
#   18. 가배두림 가산디지털점 (금천구 가산동 345-13)
#      적합도: 0.5703, 평점: 4.3, 리뷰 수: 16
#   19. 탐앤탐스 영등포역점 (영등포구 경인로 851-1)
#      적합도: 0.5702, 평점: 3.8, 리뷰 수: 130
#   20. 커피빈 홍대역점 (마포구 홍익로6길 26)
#      적합도: 0.5700, 평점: 4, 리뷰 수: 556
#   21. 로얄호스트 (영등포구 여의동 15-4)
#      적합도: 0.5697, 평점: 4.4, 리뷰 수: 14
#   22. 비하인드 (마포구 어울마당로5길 18)
#      적합도: 0.5696, 평점: 4.3, 리뷰 수: 63
#   23. 핸드픽트호텔 (동작구 상도로 120)
#      적합도: 0.5694, 평점: 4.1, 리뷰 수: 599
#   24. 스무디킹 영등포타임스퀘어점 (YEONGDEUNGPO-GU)
#      적합도: 0.5687, 평점: 3.9, 리뷰 수: 10
#   25. 할리스 커피 구로점 (구로구 구로동 811)
#      적합도: 0.5680, 평점: 3.7, 리뷰 수: 88
#   26. 까페까마르도 (강서구 화곡동 781-1)
#      적합도: 0.0000, 평점: 3.8, 리뷰 수: 5
#   27. 그랑빌 (관악구 봉천동)
#      적합도: 0.0000, 평점: 4.5, 리뷰 수: 2
#   28. 어반트리 (마포구 서교동 399-13)
#      적합도: 0.0000, 평점: 4, 리뷰 수: 1
#
# 🔹 Bar:
#   1. 스타노래연습장 (영등포구 여의동)
#      적합도: 0.5737, 평점: 3.5, 리뷰 수: 102
#   2. 투다리 구로역점 (구로구 구로동 570-115)
#      적합도: 0.5723, 평점: 4.1, 리뷰 수: 22
#   3. 와바 가산디지털단지역점 (South Korea)
#      적합도: 0.5723, 평점: 4, 리뷰 수: 23
#   4. 생활맥주 가산디지털점 (금천구 가산동 50-3 번지 대륭 포스트 타워 6 차 제 1 층 제 123 호)
#      적합도: 0.5722, 평점: 3.7, 리뷰 수: 149
#   5. 카스타운 (마포구 고산길 12)
#      적합도: 0.5722, 평점: 3.9, 리뷰 수: 49
#   6. 와바 영등포 직영점 (영등포구 영등포동3가 20)
#      적합도: 0.5721, 평점: 4.5, 리뷰 수: 2
#   7. 헤르젠 (동작구 상도동 210-34)
#      적합도: 0.5716, 평점: 3.9, 리뷰 수: 18
#   8. 치치 홍대점 (마포구 서교동 360-19)
#      적합도: 0.5713, 평점: 4.2, 리뷰 수: 81
#   9. 부엉이맥주집 (영등포구 영중로4길 9-2)
#      적합도: 0.5713, 평점: 4.1, 리뷰 수: 38
#   10. 투다리 KBS점 (영등포구 여의동 44-34)
#      적합도: 0.5713, 평점: 3.6, 리뷰 수: 23
#   11. 와라와라 (South Korea)
#      적합도: 0.5712, 평점: 3.6, 리뷰 수: 114
#   12. 생활맥주 구로디지털점 (구로구 디지털로32나길 17-12)
#      적합도: 0.5709, 평점: 4.1, 리뷰 수: 77
#   13. 치킨매니아 영등포역점 (영등포구 영등포동 618-81)
#      적합도: 0.5709, 평점: 3.8, 리뷰 수: 35
#   14. 짝태&노가리 (광명시 철산동 421)
#      적합도: 0.5709, 평점: 3.9, 리뷰 수: 15
#   15. 푸른유월 (양천구 목동동로10길 19 지하 1 층)
#      적합도: 0.5709, 평점: 4.2, 리뷰 수: 5
#   16. 치어스영등포구청점 (영등포구 당산동3가 229)
#      적합도: 0.5708, 평점: 4.6, 리뷰 수: 8
#   17. 와바 여의도 직영점 (영등포구 여의동 14-9)
#      적합도: 0.5708, 평점: 3.5, 리뷰 수: 13
#   18. bar sting (구로구 개봉제3동)
#      적합도: 0.5705, 평점: 4.3, 리뷰 수: 3
#   19. 훌랄라숯불바베큐 (구로구 고척동 271-1)
#      적합도: 0.5701, 평점: 4, 리뷰 수: 11
#   20. 통파이브 당산점 (영등포구 당산동5가 16-3)
#      적합도: 0.5697, 평점: 4, 리뷰 수: 53
#   21. 싸바 (마포구 서교동 394-25)
#      적합도: 0.5691, 평점: 4.1, 리뷰 수: 40
#   22. 비닐하우스 (영등포구 54 39 비닐하우스 1층)
#      적합도: 0.5690, 평점: 4.1, 리뷰 수: 148
#   23. 마르셀 Marcel (영등포구 marriot parkcenter B1)
#      적합도: 0.5682, 평점: 4.4, 리뷰 수: 53
#   24. 또래오래 (강서구 염창동 263)
#      적합도: 0.0000, 평점: 4, 리뷰 수: 4
#   25. MAG Live Club (관악구 서원동)
#      적합도: 0.0000, 평점: 3.7, 리뷰 수: 3
#   26. 이화주막 (영등포구 영등포동3가 17-11)
#      적합도: 0.0000, 평점: 3.5, 리뷰 수: 2
#   27. 굿뉴스 (금천구 시흥제1동 841-7)
#      적합도: 0.0000, 평점: 5, 리뷰 수: 1
#
# 🔹 Bakery:
#   1. 파리바게뜨 난곡사거리점 (관악구 난곡로 316)
#      적합도: 0.5746, 평점: 4.1, 리뷰 수: 138
#   2. 파리바게뜨 가산에이스점 (금천구 가산동 가산디지털1로 145 107호)
#      적합도: 0.5739, 평점: 3.6, 리뷰 수: 9
#   3. 파리바게뜨 영등포대우점 (영등포구 영등포동 631-13)
#      적합도: 0.5736, 평점: 4, 리뷰 수: 51
#   4. 파리바게뜨 광명3동점 (광명시 광명동 126-18)
#      적합도: 0.5732, 평점: 4.2, 리뷰 수: 30
#   5. 파리바게뜨 구로디지털점 (구로구 디지털로 285)
#      적합도: 0.5731, 평점: 3.9, 리뷰 수: 14
#   6. 파리바게뜨 당산역삼성점 (서울 영등포구 당산로 214 삼성래미안아파트 상가)
#      적합도: 0.5731, 평점: 3.6, 리뷰 수: 9
#   7. 뚜레쥬르 대방역점 (동작구 대방동 354-1)
#      적합도: 0.5727, 평점: 4.1, 리뷰 수: 84
#   8. 던킨도너츠 염창점 (강서구 염창동 252-5)
#      적합도: 0.5727, 평점: 3.6, 리뷰 수: 23
#   9. 던킨 홍대역점 (마포구 양화로 157)
#      적합도: 0.5726, 평점: 3.9, 리뷰 수: 158
#   10. 뚜레쥬르 여의서로점 (영등포구 여의동 11-11)
#      적합도: 0.5726, 평점: 4.3, 리뷰 수: 43
#   11. 던킨도너츠 구로태평양물산점 (구로구 구로동 디지털로31길 12 태평양물산본관 1층)
#      적합도: 0.5724, 평점: 3.7, 리뷰 수: 59
#   12. 파리바게뜨 염창점 (강서구 염창동 250-17)
#      적합도: 0.5724, 평점: 3.8, 리뷰 수: 23
#   13. 파리바게뜨 금천구청역점 (금천구 시흥대로63길 91)
#      적합도: 0.5722, 평점: 3.7, 리뷰 수: 15
#   14. 파리크라상 이촌점 (용산구 이촌동 301-10)
#      적합도: 0.5721, 평점: 4, 리뷰 수: 401
#   15. 코코호도목동하나점 (양천구 목동서로 133-2)
#      적합도: 0.5717, 평점: 4.5, 리뷰 수: 4
#   16. 파리크라상 여의도2호점 (영등포구 국회대로74길 12)
#      적합도: 0.5716, 평점: 4, 리뷰 수: 309
#   17. 파리바게뜨 오목교역점 (양천구 목동 405-281)
#      적합도: 0.5716, 평점: 4, 리뷰 수: 13
#   18. 파리바게뜨 여의도점 (South Korea)
#      적합도: 0.5714, 평점: 3.9, 리뷰 수: 25
#   19. 파리바게뜨 당산행복점 (영등포구 당산동4가 92-3)
#      적합도: 0.5707, 평점: 4.3, 리뷰 수: 128
#   20. 파리바게뜨 구로엘림점 (구로구 신도림로 2)
#      적합도: 0.5706, 평점: 4, 리뷰 수: 27
#   21. 파리바게뜨 유스호스텔점 (South Korea)
#      적합도: 0.5705, 평점: 4.4, 리뷰 수: 37
#   22. Bread Fit (영등포구 지하1층 133)
#      적합도: 0.5703, 평점: 4.3, 리뷰 수: 79
#   23. 시냇가에심은나무 (서울 서대문구 거북골로 7)
#      적합도: 0.5698, 평점: 5, 리뷰 수: 5
#   24. 르뽀미에 kbs신관 2층 (영등포구 여의공원로 13 KBS신관 2층)
#      적합도: 0.5692, 평점: 5, 리뷰 수: 2
#   25. 파리바게뜨 신촌점 (서대문구 연세로4길 1)
#      적합도: 0.5691, 평점: 4, 리뷰 수: 242
#   26. 안스베이커리 (광명시 광명동 200-6)
#      적합도: 0.5637, 평점: 4.5, 리뷰 수: 2
#   27. 파리바게뜨 목동파라곤 (양천구 목동 917)
#      적합도: 0.0000, 평점: 3.8, 리뷰 수: 6
#   28. 고려당 (부천시 원미구 심곡동 162-4)
#      적합도: 0.0000, 평점: 5, 리뷰 수: 1
#   29. 빵굼터 대림동점 (영등포구 대림동 1031-4)
#      적합도: 0.0000, 평점: 4, 리뷰 수: 1
#
# 🔹 Restaurant:
#   1. 삿뽀로 목동점 (양천구 신정동 목동동로 189)
#      적합도: 0.5729, 평점: 4.1, 리뷰 수: 698
#   2. 한일관 타임스퀘어점 (영등포구 영중로 15 4층)
#      적합도: 0.5727, 평점: 4, 리뷰 수: 409
#   3. 롯데리아 구로시장점 (구로구 도림로 73)
#      적합도: 0.5724, 평점: 3.6, 리뷰 수: 321
#   4. 이레 (동작구 노들로 674)
#      적합도: 0.5724, 평점: 4.8, 리뷰 수: 12
#   5. 롯데리아 신도림역점 (구로구 경인로 661)
#      적합도: 0.5720, 평점: 3.6, 리뷰 수: 181
#   6. 배스킨라빈스 구로고척 (구로구 고척동 52-200)
#      적합도: 0.5720, 평점: 4.4, 리뷰 수: 50
#   7. 막내회센타 (영등포구 도신로53길 7)
#      적합도: 0.5719, 평점: 4, 리뷰 수: 374
#   8. 맘스터치 신도림테크노마트점 (구로구 구로동 새말로 97)
#      적합도: 0.5719, 평점: 4, 리뷰 수: 95
#   9. 유진참치 (영등포구 영등포동4가 98-5)
#      적합도: 0.5716, 평점: 4.2, 리뷰 수: 79
#   10. 처갓집양념통닭 (구로구 신도림동 416-22)
#      적합도: 0.5712, 평점: 5, 리뷰 수: 2
#   11. 치킨매니아 영등포역점 (영등포구 영등포동 618-81)
#      적합도: 0.5709, 평점: 3.8, 리뷰 수: 35
#   12. 피자스쿨 영등포남부역점 (영등포구 영등포동 618-243)
#      적합도: 0.5706, 평점: 4.5, 리뷰 수: 72
#   13. 원할머니보쌈(신길점) (영등포구 신길제4동 4902-12)
#      적합도: 0.5702, 평점: 3.9, 리뷰 수: 61
#   14. 에베레스트레스토랑 영등포점 (영등포구 경인로 838-1)
#      적합도: 0.5701, 평점: 4.4, 리뷰 수: 796
#   15. 피자스쿨 구로1점 (구로구 구로제4동 766-2)
#      적합도: 0.5699, 평점: 4.1, 리뷰 수: 37
#   16. 핸드픽트호텔 (동작구 상도로 120)
#      적합도: 0.5694, 평점: 4.1, 리뷰 수: 599
#   17. 피자나라치킨공주 구로1호점 (South Korea)
#      적합도: 0.5688, 평점: 3.5, 리뷰 수: 15
#   18. 스무디킹 영등포타임스퀘어점 (YEONGDEUNGPO-GU)
#      적합도: 0.5687, 평점: 3.9, 리뷰 수: 10
#   19. 하나스시 타임스퀘어점 (영등포구 영등포동4가 441-10)
#      적합도: 0.5684, 평점: 3.8, 리뷰 수: 4
#   20. 본죽 영등포시장로터리점 (영등포구 영등포동6가 78-2)
#      적합도: 0.5679, 평점: 3.5, 리뷰 수: 11
#   21. 보릿골 (구로구 구로동 197-33)
#      적합도: 0.5677, 평점: 4, 리뷰 수: 1
#   22. 생포탄 당산점 (영등포구 당산동1가 455-1)
#      적합도: 0.0000, 평점: 5, 리뷰 수: 1
#
# 🔹 Shopping_Mall:
#   1. 지오지아 구로점 (금천구 가산동 139-1)
#      적합도: 0.5744, 평점: 3.7, 리뷰 수: 7
#   2. 맥스엔영 (영등포구 대림동 1101-14)
#      적합도: 0.5739, 평점: 3.8, 리뷰 수: 13
#   3. YA (구로구 구로동 3-25)
#      적합도: 0.5718, 평점: 5, 리뷰 수: 1
#   4. LUCE (양천구 신정4동 895-44)
#      적합도: 0.5706, 평점: 3.5, 리뷰 수: 6
#   5. 세정 타임스퀘어지점 (영등포구 영등포동4가 441-13)
#      적합도: 0.5687, 평점: 4, 리뷰 수: 3
#   6. TOUCH (구로구 신도림동 360-51)
#      적합도: 0.5683, 평점: 3.6, 리뷰 수: 5
#   7. 더슈트하우스 영등포홈플러스 (영등포구 문래동3가 55-3)
#      적합도: 0.5681, 평점: 3.6, 리뷰 수: 27
#   8. 쿠아 신세계영등포지상A (영등포구 신길동 444-10)
#      적합도: 0.0000, 평점: 4.3, 리뷰 수: 4
#   9. 금화주단 (영등포구 영등포동5가 18-1)
#      적합도: 0.0000, 평점: 3.8, 리뷰 수: 4
#   10. 천사들의합창 (영등포구 신길동 441-1)
#      적합도: 0.0000, 평점: 4.3, 리뷰 수: 3
#   11. 베베앙슈 (구로구 구로동 725-1)
#      적합도: 0.0000, 평점: 4, 리뷰 수: 2
#   12. 미네랄 (양천구 신정2동 117-5)
#      적합도: 0.0000, 평점: 3.5, 리뷰 수: 2
#   13. 토트라 (양천구 신정동 888-28)
#      적합도: 0.0000, 평점: 4, 리뷰 수: 1

# %%
target_name = "N서울타워"  # 확인하고 싶은 명소 이름

for place in all_places:
    if target_name in place["name"]:
        print(f"📍 {place['name']} ({place['type']})")
        print(f"   적합도: {place.get('transformer_score', '없음')}")
# Out:
# 📍 N서울타워 (tourist_attraction)
#    적합도: 0.5089

# %%
"""
Transformer를 활용한 사용자 희망 사항과 리뷰 분석 : Fine-Tuning 불가하며 생각보다 훌륭한 성능을 보이지 못하였다고 판단된다.
이에 키워드 기반 점수 생성형태로 점수를 부여하기로 결정

"""
